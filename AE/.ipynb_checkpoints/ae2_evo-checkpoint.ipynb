# %% [markdown]
# # AE2

# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import math

# %%
# find all desks in this vertical path
# calculate vertical space between each found rectangle
# if there is vertical space > height, put the desk over there
# if there is no such space, then put it under lowest collision
# if there are no collisions, put it in the highest available space in vertical path

# %%
""" Config """
DEBUG = False

# %%
def sort_by_real_value(data: pd.DataFrame):
    """ sorts by value per one unit of measure, modifies data inplace """
    data.columns = ['width', 'height', 'value']
    data['real_value'] = data['value'] / (data['width'] * data['height'])
    data.sort_values(by='real_value', ascending=False, inplace=True)
    data.drop(['real_value'], axis=1, inplace=True)
    data.reset_index(drop=True, inplace=True)
    return data

# %%
class Stock:

    def __init__(self, radius):
        self.radius = radius
        self.rectangles = np.empty((0, 5)) # bottom left corner x, y, width, height, value

    def is_within_circle(self, x, y, width, height):
        corners = [(x, y), (x + width, y), (x, y + height), (x + width, y + height)]
        for corner in corners:
            if np.sqrt(corner[0]**2 + corner[1]**2) > self.radius:
                return False
        return True

    def is_not_overlapping(self, x, y, width, height):
        for rect in self.rectangles:
            if (x + width > rect[0] and x < rect[0] + rect[2]) and (y + height > rect[1] and y < rect[1] + rect[3]):
                return False
        return True
    
    def visualize(self):
        fig, ax = plt.subplots()
    
        circle = plt.Circle((0, 0), self.radius, color='blue', fill=False, linewidth=2)
        ax.add_patch(circle)
    
        for rect in self.rectangles:
            x, y, width, height, _ = rect
            rectangle = plt.Rectangle((x, y), width, height, edgecolor='black', facecolor='yellow', linewidth=1)
            ax.add_patch(rectangle)
    
        ax.set_aspect('equal', 'box')
        offset = int(self.radius / 16)
        ax.set_xlim(-self.radius - offset, self.radius + offset)
        ax.set_ylim(-self.radius - offset, self.radius + offset)
        ax.set_title(f'R = {self.radius}')
    
        plt.show()

    def fitness(self):
        return np.sum(self.rectangles, axis=0)[4]

    def get_vertical_collisions(self, x_left, x_right):
        vertical_collisions = []
        bottom_point = self.find_highest_point(x_left, x_right)
        
        for rect in self.rectangles:
            rect_left = rect[0]
            rect_right = rect[0] + rect[2]
            if (x_right > rect_left and x_left < rect_right) and (rect[1] < int(bottom_point[1])):
                vertical_collisions.append(rect)
                
        bottom_point = self.find_highest_point(x_left, x_right)
        vertical_collisions.append(np.array([int(bottom_point[0]), int(bottom_point[1]), x_right-x_left, self.radius - int(bottom_point[1]), 0]))
        return vertical_collisions
    
    def calculate_vertical_spaces(self, vertical_collisions):
        
        vertical_collisions = sorted(vertical_collisions, key=lambda r: r[1])
        vertical_spaces = [(-self.radius, vertical_collisions[0][1])]

        for i in range(1, len(vertical_collisions)):
            bottom = vertical_collisions[i-1][1] + vertical_collisions[i-1][3]
            top = vertical_collisions[i][1]
            vertical_spaces.append((bottom, top))

        return vertical_spaces
    
    def find_highest_point(self, x1, x2):
        num_points = int((x2 - x1) * 2)
        points = []
        for i in range(num_points):
            angle = 2 * math.pi * i / num_points
            x = (self.radius - 1) * math.cos(angle)
            y = (self.radius - 1) * math.sin(angle)
            if x > x1 and x < x2 and y >= 0:
                points.append([x, y])
        points = np.array(points)
        return points[np.argmin(points[:, 1])]

class EA:

    def __init__(self, data, radius, population_size=10, generations=5):
        self.data = sort_by_real_value(data.copy()) # desk['width'], desk['height'], desk['value']
        self.radius = radius
        self.population_size = population_size
        self.generations = generations
        self.population = []
    
    def evaluation(self, population):
        return [stock.fitness() for stock in population]

    def initialize(self, n_retries=20):

        for individual in range(self.population_size):
            stock = Stock(self.radius)
            for i, desk in self.data.iterrows():
                # print(f"DESK {i}")
                tries = 0
                while tries < n_retries:
                    x = random.uniform(-self.radius, self.radius - desk['width'])
                    y = random.uniform(-self.radius, self.radius - desk['height'])
                    if stock.is_within_circle(x, y, desk['width'], desk['height']) and stock.is_not_overlapping(x, y, desk['width'], desk['height']):
                        stock.rectangles = np.vstack((stock.rectangles, [x, y, desk['width'], desk['height'], desk['value']]))
                    else:
                        tries += 1
            self.population.append(stock)

    def mutation(self, individual: Stock, mutation_rate=0.7, n_retries=100):
        if np.random.rand() < mutation_rate:
            k = 0
            # modify
            for i in range(len(individual.rectangles)):
                rect = individual.rectangles[0]
                individual.rectangles =  individual.rectangles[1:]
                desk = {'width': rect[2], 'height': rect[3], 'value': rect[4]}
                x, y = rect[0], rect[1]
                try:
                    vertical_collisions = individual.get_vertical_collisions(x, x + desk['width'])
                except Exception as e:
                    individual.rectangles = np.vstack((individual.rectangles, rect))
                    continue
                vertical_spaces = individual.calculate_vertical_spaces(vertical_collisions)
    
                if DEBUG:
                    print('Collisions:', vertical_collisions)
                    print('Spaces:', vertical_spaces)
                
                placed = False
                for (bottom, top) in reversed(vertical_spaces):
                    diff = top - bottom
                    if DEBUG:
                        print('DIFF:', diff)
                    if diff >= desk['height']:
                        y = top - desk['height']
                        if individual.is_within_circle(x, y, desk['width'], desk['height']) and individual.is_not_overlapping(x, y, desk['width'], desk['height']):
                            individual.rectangles = np.vstack((individual.rectangles, [x, y, desk['width'], desk['height'], desk['value']]))
                            k += 1
                            placed = True
                            if DEBUG:
                                print(f"Rectangle {k} placed:", x, y, desk['width'], desk['height'])
                            break
                if not placed:
                    individual.rectangles = np.vstack((individual.rectangles, rect))
            # add new           
            for i, desk in self.data.iterrows():
                tries = 0
                while tries < n_retries:
                    x = random.uniform(-self.radius, self.radius - desk['width'])
                    y = random.uniform(-self.radius, self.radius - desk['height'])
                    if individual.is_within_circle(x, y, desk['width'], desk['height']) and individual.is_not_overlapping(x, y, desk['width'], desk['height']):
                        individual.rectangles = np.vstack((individual.rectangles, [x, y, desk['width'], desk['height'], desk['value']]))
                    else:
                        tries += 1
        return individual
    
    def train(self, n_retries=100):
        self.initialize(n_retries=n_retries)
        for generation in range(self.generations):
            
            new_population = []
            
            # no crossover

            if not generation == 0:
                for i, parent in enumerate(self.population):
                    child = self.mutation(parent, n_retries)
                    self.population[i] = child 

            fitness = self.evaluation(self.population)
            best_individual = self.population[np.argmax(fitness)]
            best_fitness = best_individual.fitness()
            # best_individual.visualize()
            print(f"Generation {generation+1}: best individual: {best_individual}, fitness: {best_fitness}")

        fitness = self.evaluation(self.population)
        best_individual = self.population[np.argmax(fitness)]
        best_individual.visualize()
        best_fitness = best_individual.fitness()
        return best_individual

# %% [markdown]
# ## Dane

# %% [markdown]
# #### R = 800

# %%
r800 = pd.read_csv("cutting/r800.csv", header=None)

# %%
ea = EA(r800, 800, population_size=20, generations=30)
ea.train(n_retries=150)
# Out:
# Generation 1: best individual: <__main__.Stock object at 0x000001C8EDCE0710>, fitness: 22440.0
# Generation 2: best individual: <__main__.Stock object at 0x000001C8EE116110>, fitness: 27940.0
# Generation 3: best individual: <__main__.Stock object at 0x000001C8EE116110>, fitness: 30340.0
# Generation 4: best individual: <__main__.Stock object at 0x000001C8EE116110>, fitness: 31140.0
# Generation 5: best individual: <__main__.Stock object at 0x000001C8EE116110>, fitness: 32380.0
# Generation 6: best individual: <__main__.Stock object at 0x000001C8EE116310>, fitness: 32540.0
# Generation 7: best individual: <__main__.Stock object at 0x000001C8EE116310>, fitness: 32940.0
# Generation 8: best individual: <__main__.Stock object at 0x000001C8EE116310>, fitness: 33340.0
# Generation 9: best individual: <__main__.Stock object at 0x000001C8EE116110>, fitness: 34020.0
# Generation 10: best individual: <__main__.Stock object at 0x000001C8EE116110>, fitness: 34060.0
# Generation 11: best individual: <__main__.Stock object at 0x000001C8EE116110>, fitness: 34500.0
# Generation 12: best individual: <__main__.Stock object at 0x000001C8EE116110>, fitness: 34500.0
# Generation 13: best individual: <__main__.Stock object at 0x000001C8EE116110>, fitness: 34500.0
# Generation 14: best individual: <__main__.Stock object at 0x000001C8EE116110>, fitness: 34500.0
# Generation 15: best individual: <__main__.Stock object at 0x000001C8EE116110>, fitness: 34940.0
# Generation 16: best individual: <__main__.Stock object at 0x000001C8EE116110>, fitness: 35380.0
# Generation 17: best individual: <__main__.Stock object at 0x000001C8EE116110>, fitness: 35380.0
# Generation 18: best individual: <__main__.Stock object at 0x000001C8EE116110>, fitness: 35380.0
# Generation 19: best individual: <__main__.Stock object at 0x000001C8EE116110>, fitness: 35380.0
# Generation 20: best individual: <__main__.Stock object at 0x000001C8EE116110>, fitness: 35380.0
# Generation 21: best individual: <__main__.Stock object at 0x000001C8EE116110>, fitness: 35380.0
# Generation 22: best individual: <__main__.Stock object at 0x000001C8EE116110>, fitness: 35380.0
# Generation 23: best individual: <__main__.Stock object at 0x000001C8EE116110>, fitness: 35380.0
# Generation 24: best individual: <__main__.Stock object at 0x000001C8EE116110>, fitness: 35380.0
# Generation 25: best individual: <__main__.Stock object at 0x000001C8EE116110>, fitness: 35380.0
# Generation 26: best individual: <__main__.Stock object at 0x000001C8EE116110>, fitness: 35380.0
# Generation 27: best individual: <__main__.Stock object at 0x000001C8EE116110>, fitness: 35380.0
# Generation 28: best individual: <__main__.Stock object at 0x000001C8EE116110>, fitness: 35380.0
# Generation 29: best individual: <__main__.Stock object at 0x000001C8EE116110>, fitness: 35380.0
# Generation 30: best individual: <__main__.Stock object at 0x000001C8EE116110>, fitness: 35380.0

# %% [markdown]
# #### 850

# %%
r850 = pd.read_csv("cutting/r850.csv", header=None)

# %%
ea = EA(r850, 850, population_size=10, generations=20)
ea.train(n_retries=120)
# Out:
# Generation 1: best individual: <__main__.Stock object at 0x000001C8EDDDB210>, fitness: 285040.0
# Generation 2: best individual: <__main__.Stock object at 0x000001C8EE070690>, fitness: 300560.0
# Generation 3: best individual: <__main__.Stock object at 0x000001C8EE070690>, fitness: 309260.0
# Generation 4: best individual: <__main__.Stock object at 0x000001C8EE070690>, fitness: 318740.0
# Generation 5: best individual: <__main__.Stock object at 0x000001C8EDCDAB90>, fitness: 322820.0
# Generation 6: best individual: <__main__.Stock object at 0x000001C8EDCDAB90>, fitness: 326480.0
# Generation 7: best individual: <__main__.Stock object at 0x000001C8EDCDAB90>, fitness: 328610.0
# Generation 8: best individual: <__main__.Stock object at 0x000001C8EDCDAB90>, fitness: 329870.0
# Generation 9: best individual: <__main__.Stock object at 0x000001C8EDCDAB90>, fitness: 335240.0
# Generation 10: best individual: <__main__.Stock object at 0x000001C8EDCDAB90>, fitness: 336500.0
# Generation 11: best individual: <__main__.Stock object at 0x000001C8EDCDAB90>, fitness: 337340.0
# Generation 12: best individual: <__main__.Stock object at 0x000001C8EDCDAB90>, fitness: 338630.0
# Generation 13: best individual: <__main__.Stock object at 0x000001C8EDCDAB90>, fitness: 340070.0
# Generation 14: best individual: <__main__.Stock object at 0x000001C8EDCDAB90>, fitness: 341300.0
# Generation 15: best individual: <__main__.Stock object at 0x000001C8EDCDAB90>, fitness: 341840.0
# Generation 16: best individual: <__main__.Stock object at 0x000001C8EDCDAB90>, fitness: 342380.0
# Generation 17: best individual: <__main__.Stock object at 0x000001C8EDCDAB90>, fitness: 343070.0
# Generation 18: best individual: <__main__.Stock object at 0x000001C8EDCDAB90>, fitness: 343640.0
# Generation 19: best individual: <__main__.Stock object at 0x000001C8EDCDAB90>, fitness: 343790.0
# Generation 20: best individual: <__main__.Stock object at 0x000001C8EDCDAB90>, fitness: 344390.0

# %% [markdown]
# #### 1000

# %%
r1000 = pd.read_csv("cutting/r1000.csv", header=None)

# %%
ea3 = EA(r1000, 1000, population_size=10, generations=20)
ea3.train(n_retries=120)
# Out:
# Generation 1: best individual: <__main__.Stock object at 0x000001C8EE237150>, fitness: 17340.0
# Generation 2: best individual: <__main__.Stock object at 0x000001C8EE67BF90>, fitness: 18300.0
# Generation 3: best individual: <__main__.Stock object at 0x000001C8EE3B6D10>, fitness: 19180.0
# Generation 4: best individual: <__main__.Stock object at 0x000001C8EE3B6D10>, fitness: 19760.0
# Generation 5: best individual: <__main__.Stock object at 0x000001C8EE3B6D10>, fitness: 19880.0
# Generation 6: best individual: <__main__.Stock object at 0x000001C8EE3B6D10>, fitness: 19960.0
# Generation 7: best individual: <__main__.Stock object at 0x000001C8EE3B6D10>, fitness: 20400.0
# Generation 8: best individual: <__main__.Stock object at 0x000001C8EE3B6D10>, fitness: 20440.0
# Generation 9: best individual: <__main__.Stock object at 0x000001C8EE3B6D10>, fitness: 20560.0
# Generation 10: best individual: <__main__.Stock object at 0x000001C8EE3B6D10>, fitness: 20600.0
# Generation 11: best individual: <__main__.Stock object at 0x000001C8EE3B6D10>, fitness: 20600.0
# Generation 12: best individual: <__main__.Stock object at 0x000001C8EE3B6D10>, fitness: 20680.0
# Generation 13: best individual: <__main__.Stock object at 0x000001C8EE3B6D10>, fitness: 20680.0
# Generation 14: best individual: <__main__.Stock object at 0x000001C8EE3B6D10>, fitness: 20680.0
# Generation 15: best individual: <__main__.Stock object at 0x000001C8EE3B6D10>, fitness: 20720.0
# Generation 16: best individual: <__main__.Stock object at 0x000001C8EE3B6D10>, fitness: 20760.0
# Generation 17: best individual: <__main__.Stock object at 0x000001C8EE3B6D10>, fitness: 20760.0
# Generation 18: best individual: <__main__.Stock object at 0x000001C8EE3B6D10>, fitness: 20760.0
# Generation 19: best individual: <__main__.Stock object at 0x000001C8EE3B6D10>, fitness: 20840.0
# Generation 20: best individual: <__main__.Stock object at 0x000001C8EE3B6D10>, fitness: 20840.0

# %% [markdown]
# #### 1100

# %%
r1100 = pd.read_csv("cutting/r1100.csv", header=None)

# %%
ea4 = EA(r1100, 1100, population_size=20, generations=50)
ea4.train(n_retries=200)
# Out:
# Generation 1: best individual: <__main__.Stock object at 0x000001C8EE6BB650>, fitness: 23840.0
# Generation 2: best individual: <__main__.Stock object at 0x000001C8EE6BB650>, fitness: 25320.0
# Generation 3: best individual: <__main__.Stock object at 0x000001C8EE282890>, fitness: 26460.0
# Generation 4: best individual: <__main__.Stock object at 0x000001C8EE282890>, fitness: 26780.0
# Generation 5: best individual: <__main__.Stock object at 0x000001C8EE282890>, fitness: 26880.0
# Generation 6: best individual: <__main__.Stock object at 0x000001C8ED7D3C10>, fitness: 26940.0
# Generation 7: best individual: <__main__.Stock object at 0x000001C8EE282890>, fitness: 27060.0
# Generation 8: best individual: <__main__.Stock object at 0x000001C8EE282890>, fitness: 27060.0
# Generation 9: best individual: <__main__.Stock object at 0x000001C8EE282890>, fitness: 27100.0
# Generation 10: best individual: <__main__.Stock object at 0x000001C8EE6BB650>, fitness: 27300.0
# Generation 11: best individual: <__main__.Stock object at 0x000001C8EE6BB650>, fitness: 27340.0
# Generation 12: best individual: <__main__.Stock object at 0x000001C8EE6BB650>, fitness: 27340.0
# Generation 13: best individual: <__main__.Stock object at 0x000001C8EE6BB650>, fitness: 27340.0
# Generation 14: best individual: <__main__.Stock object at 0x000001C8EE6BB650>, fitness: 27340.0
# Generation 15: best individual: <__main__.Stock object at 0x000001C8EE6BB650>, fitness: 27340.0
# Generation 16: best individual: <__main__.Stock object at 0x000001C8EE6BB650>, fitness: 27380.0
# Generation 17: best individual: <__main__.Stock object at 0x000001C8EE6BB650>, fitness: 27380.0
# Generation 18: best individual: <__main__.Stock object at 0x000001C8EE6BB650>, fitness: 27380.0
# Generation 19: best individual: <__main__.Stock object at 0x000001C8EE6BB650>, fitness: 27380.0
# Generation 20: best individual: <__main__.Stock object at 0x000001C8EE6BB650>, fitness: 27380.0
# Generation 21: best individual: <__main__.Stock object at 0x000001C8EE6BB650>, fitness: 27380.0
# Generation 22: best individual: <__main__.Stock object at 0x000001C8EE6BB650>, fitness: 27380.0
# Generation 23: best individual: <__main__.Stock object at 0x000001C8EE6BB650>, fitness: 27380.0
# Generation 24: best individual: <__main__.Stock object at 0x000001C8EE6BB650>, fitness: 27380.0
# Generation 25: best individual: <__main__.Stock object at 0x000001C8EE6BB650>, fitness: 27380.0
# Generation 26: best individual: <__main__.Stock object at 0x000001C8EE6BB650>, fitness: 27420.0
# Generation 27: best individual: <__main__.Stock object at 0x000001C8EE6BB650>, fitness: 27420.0
# Generation 28: best individual: <__main__.Stock object at 0x000001C8EE6BB650>, fitness: 27420.0
# Generation 29: best individual: <__main__.Stock object at 0x000001C8EE6BB650>, fitness: 27420.0
# Generation 30: best individual: <__main__.Stock object at 0x000001C8EE6BB650>, fitness: 27420.0
# Generation 31: best individual: <__main__.Stock object at 0x000001C8EE6BB650>, fitness: 27420.0
# Generation 32: best individual: <__main__.Stock object at 0x000001C8EE6BB650>, fitness: 27420.0
# Generation 33: best individual: <__main__.Stock object at 0x000001C8EE6BB650>, fitness: 27420.0
# Generation 34: best individual: <__main__.Stock object at 0x000001C8EE6BB650>, fitness: 27420.0
# Generation 35: best individual: <__main__.Stock object at 0x000001C8EE6BB650>, fitness: 27420.0
# Generation 36: best individual: <__main__.Stock object at 0x000001C8EE6BB650>, fitness: 27420.0
# Generation 37: best individual: <__main__.Stock object at 0x000001C8EE6BB650>, fitness: 27420.0
# Generation 38: best individual: <__main__.Stock object at 0x000001C8EE6BB650>, fitness: 27420.0
# Generation 39: best individual: <__main__.Stock object at 0x000001C8EE282890>, fitness: 27440.0
# Generation 40: best individual: <__main__.Stock object at 0x000001C8EE282890>, fitness: 27440.0
# Generation 41: best individual: <__main__.Stock object at 0x000001C8EE282890>, fitness: 27440.0
# Generation 42: best individual: <__main__.Stock object at 0x000001C8EE282890>, fitness: 27440.0
# Generation 43: best individual: <__main__.Stock object at 0x000001C8EE282890>, fitness: 27440.0
# Generation 44: best individual: <__main__.Stock object at 0x000001C8EE282890>, fitness: 27480.0
# Generation 45: best individual: <__main__.Stock object at 0x000001C8EE282890>, fitness: 27480.0
# Generation 46: best individual: <__main__.Stock object at 0x000001C8EE282890>, fitness: 27480.0
# Generation 47: best individual: <__main__.Stock object at 0x000001C8EE282890>, fitness: 27480.0
# Generation 48: best individual: <__main__.Stock object at 0x000001C8EE282890>, fitness: 27480.0
# Generation 49: best individual: <__main__.Stock object at 0x000001C8EE282890>, fitness: 27480.0
# Generation 50: best individual: <__main__.Stock object at 0x000001C8EE282890>, fitness: 27480.0

# %% [markdown]
# #### 1200

# %%
r1200 = pd.read_csv("cutting/r1200.csv", header=None)

# %%
ea5 = EA(r1200, 1200, population_size=20, generations=35)
ea5.train(n_retries=120)
# Out:
# Generation 1: best individual: <__main__.Stock object at 0x00000206FB643190>, fitness: 22820.0
# Generation 2: best individual: <__main__.Stock object at 0x00000206FC425AD0>, fitness: 25600.0
# Generation 3: best individual: <__main__.Stock object at 0x00000206FC425AD0>, fitness: 26900.0
# Generation 4: best individual: <__main__.Stock object at 0x00000206FC425AD0>, fitness: 27280.0
# Generation 5: best individual: <__main__.Stock object at 0x00000206FB643190>, fitness: 28060.0
# Generation 6: best individual: <__main__.Stock object at 0x00000206FC403F10>, fitness: 28480.0
# Generation 7: best individual: <__main__.Stock object at 0x00000206FC425AD0>, fitness: 28860.0
# Generation 8: best individual: <__main__.Stock object at 0x00000206FC403F10>, fitness: 29180.0
# Generation 9: best individual: <__main__.Stock object at 0x00000206FC403F10>, fitness: 29220.0
# Generation 10: best individual: <__main__.Stock object at 0x00000206FC425AD0>, fitness: 29420.0
# Generation 11: best individual: <__main__.Stock object at 0x00000206FC425AD0>, fitness: 29420.0
# Generation 12: best individual: <__main__.Stock object at 0x00000206FC425AD0>, fitness: 29620.0
# Generation 13: best individual: <__main__.Stock object at 0x00000206FC403F10>, fitness: 29660.0
# Generation 14: best individual: <__main__.Stock object at 0x00000206FC403F10>, fitness: 29700.0
# Generation 15: best individual: <__main__.Stock object at 0x00000206FC403F10>, fitness: 29700.0
# Generation 16: best individual: <__main__.Stock object at 0x00000206FC425AD0>, fitness: 29820.0
# Generation 17: best individual: <__main__.Stock object at 0x00000206FC425AD0>, fitness: 29820.0
# Generation 18: best individual: <__main__.Stock object at 0x00000206FC425AD0>, fitness: 29860.0
# Generation 19: best individual: <__main__.Stock object at 0x00000206FC425AD0>, fitness: 29900.0
# Generation 20: best individual: <__main__.Stock object at 0x00000206FC425AD0>, fitness: 29900.0
# Generation 21: best individual: <__main__.Stock object at 0x00000206FC425AD0>, fitness: 29900.0
# Generation 22: best individual: <__main__.Stock object at 0x00000206FC425AD0>, fitness: 29940.0
# Generation 23: best individual: <__main__.Stock object at 0x00000206FC425AD0>, fitness: 29980.0
# Generation 24: best individual: <__main__.Stock object at 0x00000206FC425AD0>, fitness: 29980.0
# Generation 25: best individual: <__main__.Stock object at 0x00000206FC425AD0>, fitness: 30020.0
# Generation 26: best individual: <__main__.Stock object at 0x00000206FC425AD0>, fitness: 30020.0
# Generation 27: best individual: <__main__.Stock object at 0x00000206FC425AD0>, fitness: 30020.0
# Generation 28: best individual: <__main__.Stock object at 0x00000206FC425AD0>, fitness: 30060.0
# Generation 29: best individual: <__main__.Stock object at 0x00000206FC425AD0>, fitness: 30060.0
# Generation 30: best individual: <__main__.Stock object at 0x00000206FC425AD0>, fitness: 30060.0
# Generation 31: best individual: <__main__.Stock object at 0x00000206FC425AD0>, fitness: 30060.0
# Generation 32: best individual: <__main__.Stock object at 0x00000206FC425AD0>, fitness: 30100.0
# Generation 33: best individual: <__main__.Stock object at 0x00000206FC425AD0>, fitness: 30140.0
# Generation 34: best individual: <__main__.Stock object at 0x00000206FC425AD0>, fitness: 30220.0
# Generation 35: best individual: <__main__.Stock object at 0x00000206FC425AD0>, fitness: 30220.0

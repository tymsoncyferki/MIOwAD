# %% [markdown]
# # NN4
# Tymoteusz Urban

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
import time
import copy
from sklearn.metrics import f1_score
from tqdm import tqdm

# %%
class NeuralNetwork:
    
    """
    Implementation of multi layer perceptron

    Attributes
    -----------
    model_type : str
        model type, regressor or classifier
    layers : List
        list of layer sizes
    num_layers : int
        number of layers
    init_function : func
        
    """
    
    def __init__(self, layers, initalization='xavier', model_type='regression', weights=None, biases=None, activations=None):
        """
        activations - list of available functions: 'sigmoid', 'linear', 'tanh', 'relu', 'softmax' ('softmax' can be used only on the last layer)
        initialization - available types: 'xavier', 'he', 'uniform'
        model_type - available types: 'regression', 'classification'
        """        
        self.layers = layers
        self.num_layers = len(layers)
        
        initialization_functions = {
            'xavier': self.xavier_init,
            'he': self.he_init,
            'uniform': self.uniform_init
        }
        self.init_function = initialization_functions.get(initalization)
        
        assert model_type in ['regression', 'classification']
        self.model_type = model_type
        
        if weights is None:
            self.weights = [self.init_function(layers[i-1], layers[i]) for i in range(1, self.num_layers)]
        else:
            self.weights = weights
        
        if biases is None:
            self.biases = [self.init_function(layers[i]) for i in range(1, self.num_layers)]
        else:
            self.biases = biases
        
        if activations is None:
            if self.model_type == 'regression':
                self.activations = ['sigmoid' for i in range(1, self.num_layers - 1)] + ['linear']
            elif self.model_type == 'classification':
                self.activations = ['sigmoid' for i in range(1, self.num_layers - 1)] + ['softmax']
        else:
            self.activations = activations
        
        self.velocities_weights = [self.zeros_init(layers[i-1], layers[i]) for i in range(1, self.num_layers)]
        self.velocities_biases = [self.zeros_init(layers[i]) for i in range(1, self.num_layers)]
        
        activation_functions = {
            'sigmoid': self._sigmoid,
            'linear': self._linear,
            'softmax': self._softmax,
            'tanh': self._tanh,
            'relu': self._relu
        }
        self.activation_funcs = list(map(lambda x: activation_functions.get(x), self.activations))
    
    def _sigmoid(self, z):
        return 1 / (1 + np.exp(-z))

    def _linear(self, z):
        return z
    
    def _tanh(self, z):
        return (np.exp(z) - np.exp(-z)) / (np.exp(z) + np.exp(-z))
    
    def _relu(self, z):
        return np.maximum(z, 0)
    
    def _softmax(self, z):
        exp_z = np.exp(z - np.max(z, axis=1, keepdims=True))
        return exp_z / exp_z.sum(axis=1, keepdims=True)
    
    def tanh_derivative(self, a):
        """calculates tanh'(z) where a = tanh(z)"""
        return 1 - (a ** 2)
    
    def sigmoid_derivative(self, a):
        """calculates sigm'(z) where a = sigm(z)"""
        return a * (1-a)
    
    def relu_derivative(self, z):
        return np.maximum(0, np.sign(z))
    
    def xavier_init(self, n_in, n_out=None):
        if n_out is None:
            n_out = n_in
            variance = 1 / n_out
            stddev = np.sqrt(variance)
            return np.random.normal(0, stddev, n_out)
        variance = 2 / (n_in + n_out)
        stddev = np.sqrt(variance)
        return np.random.normal(0, stddev, (n_in, n_out))
        
    def he_init(self, n_in, n_out=None):
        if n_out is None:
            variance = 2 / n_in
            stddev = np.sqrt(variance)
            return np.random.normal(0, stddev, n_in)
        variance = 2 / n_in
        stddev = np.sqrt(variance)
        return np.random.normal(0, stddev, (n_in, n_out))
    
    def zeros_init(self, n_in, n_out=None):
        if n_out is None:
            return np.zeros(n_in)
        return np.zeros((n_in, n_out))
    
    def uniform_init(self, n_in, n_out=None):
        if n_out is None:
            return np.random.uniform(0, 1, n_in)
        return np.random.uniform(0, 1, (n_in, n_out))
    
    def feedforward(self, a, return_activations=False):
        if return_activations:
            activations = [a]
            for w, b, func in zip(self.weights, self.biases, self.activation_funcs):
                z = np.dot(a, w) + b
                a = func(z)
                activations.append(a)
            return activations
        else:
            for w, b, func in zip(self.weights, self.biases, self.activation_funcs):
                z = np.dot(a, w) + b
                a = func(z)
            return a
    
    def predict(self, X, label=False):
        """ if to use label_predictions function """
        if label:
            return label_predictions(self.feedforward(X))
        else:
            return self.feedforward(X)
    
    def mse(self, X, y, resize=False, denormalize=None):
        """
        first predictions are made, then denormalized and then mse is calculated
        
        denormalize - a tuple (mean, std)
        """
        if resize:
            X = X.to_numpy().reshape(-1, 1)
            y = y.to_numpy().reshape(-1, 1)
        predictions = self.predict(X)
        if denormalize:
            predictions = destandardize_data(predictions, denormalize)
        return np.mean((predictions - y) ** 2)
    
    def f1_score(self, X, y_true, average='weighted'):
        """
        calculates f1 score. 
        y_true : 2 dimensional array with probabilities
        average: 'weighted', 'macro'
        """
        predictions = self.predict(X)
        y_pred = label_predictions(predictions)
        y_true = label_predictions(y_true)
        f1 = f1_score(y_true, y_pred, average='weighted')
        return f1

    def cross_entropy(self, X, y):
        """ Calculates cross entropy loss """
        predictions = self.predict(X)
        epsilon = 1e-9  # Small constant to avoid taking the logarithm of zero
        return -np.mean(np.sum(y * np.log(predictions + epsilon), axis=1))
    
    def loss(self, X, y, resize=False, denormalize=None, test=False):
        """ returns appriopriate loss """
        if self.model_type == 'regression':
            return self.mse(X, y, resize=resize, denormalize=denormalize)
        elif self.model_type == 'classification':
            if test:
                return self.f1_score(X, y)
            else:
                return self.cross_entropy(X, y)
    
    def plot_classes(self, data):
        """ plots predicted classes for classifcation data. plot based only on first two columns of passed data. """
        colors = self.predict(data, label=True)
        sns.scatterplot(x=data[:,0], y=data[:,1], hue=colors)
    
    def backward(self, X, y, l2_lambda=None):
        """backpropagation, returns partial derevatives"""
        # feedforward
        activations = self.feedforward(X, return_activations=True)
        deltas = [None] * len(self.weights)
        # output error
        if self.activations[-1] == "softmax":
            deltas[-1] = activations[-1] - y 
        elif self.activations[-1] == "linear": # linear
            deltas[-1] = activations[-1] - y
        elif self.activations[-1] == "sigmoid":
            deltas[-1] = (activations[-1] - y) * self.sigmoid_derivative(activations[-1])
        elif self.activations[-1] == "relu" or self.activations[-1] == "tanh":
            raise AssertionError('tanh and relu cant be used on the last layer')
        # calculate neurons' errors using backpropagation 
        for i in reversed(range(len(deltas) - 1)):
            if self.activations[i] == "sigmoid":
                # calculate error delta_l = delta_{l+1} x w_{l+1} * sigmoid'(a_{l})
                deltas[i] = np.dot(deltas[i+1], self.weights[i+1].T) * self.sigmoid_derivative(activations[i+1])
            elif self.activations[i] == "linear":
                deltas[i] = np.dot(deltas[i+1], self.weights[i+1].T)
            elif self.activations[i] == "relu":
                deltas[i] = np.dot(deltas[i+1], self.weights[i+1].T) * self.relu_derivative(activations[i+1])
            elif self.activations[i] == "tanh":    
                deltas[i] = np.dot(deltas[i+1], self.weights[i+1].T) * self.tanh_derivative(activations[i+1])
            elif self.activations[i] == "softmax":
                raise AssertionError("softmax can be used only on the last layer")
        L = len(self.weights)
        weights_gradient = [None] * L
        biases_gradient = [None] * L
        # calculate partial derevatives of cost function
        for i in range(L):
            # activations array is longer (so activations[l] in reality is a_{l-1})
            weights_gradient[i] = np.dot(activations[i].T, deltas[i])
            biases_gradient[i] = np.sum(deltas[i], axis=0)
            
            if l2_lambda is not None:
                n = len(self.weights[i])
                weights_gradient[i] = weights_gradient[i] + (l2_lambda / n) * self.weights[i]
            
        return weights_gradient, biases_gradient
        
    def update_weights(self, X, y, learning_rate, optimize=None, optimize_param=0.9, l2_lambda=None):
        """
        updates weights using gradient descent
        """
        m = len(X)
        weights_gradient, biases_gradient = self.backward(X, y, l2_lambda)
        for i in range(len(self.weights)):
            
            if optimize is None:
                self.weights[i] = self.weights[i] - (learning_rate/m) * weights_gradient[i]
                self.biases[i] = self.biases[i] - (learning_rate/m) * biases_gradient[i]
            
            elif optimize == 'moment':
                self.velocities_weights[i] = weights_gradient[i] + self.velocities_weights[i] * optimize_param
                self.velocities_biases[i] = biases_gradient[i] + self.velocities_biases[i] * optimize_param
            
                self.weights[i] = self.weights[i] - (learning_rate/m) * self.velocities_weights[i]
                self.biases[i] = self.biases[i] - (learning_rate/m) * self.velocities_biases[i]            
            
            elif optimize == 'rmsprop':
                self.velocities_weights[i] = optimize_param * self.velocities_weights[i] + (1-optimize_param) * (weights_gradient[i]**2)
                self.velocities_biases[i] = optimize_param * self.velocities_biases[i] + (1-optimize_param) * (biases_gradient[i]**2)
                
                self.weights[i] = self.weights[i] - (learning_rate/m) * (weights_gradient[i]/np.sqrt(self.velocities_weights[i]))
                self.biases[i] = self.biases[i] - (learning_rate/m) * (biases_gradient[i]/np.sqrt(self.velocities_biases[i]))
    
    def create_batches(self, X, y, batch_size):
        """ creates batches """
        N = len(X)
        combined_data = list(zip(X, y))
        np.random.shuffle(combined_data)

        X_shuffled = np.array(list(zip(*combined_data))[0])
        y_shuffled = np.array(list(zip(*combined_data))[1])

        X_mini_batches = [X_shuffled[k:k+batch_size] for k in range(0, N, batch_size)]
        y_mini_batches = [y_shuffled[k:k+batch_size] for k in range(0, N, batch_size)]
        return X_mini_batches, y_mini_batches
        
    def train(self, X, y, learning_rate=0.001, epochs=10000, batch_size=None, return_history=False, window_size=1,
              optimize=None, optimize_param=0.9, l2_lambda=None, val_stopping_k=None, test_metric='f1', X_val=None, y_val=None,
              X_test=None, y_test=None, cutoff=None, cutoff_inverse=False, resize=False, denormalize=None, 
              info_interval=500, mute_print=False):
        """
        To test and print MSE on testset, X_test and y_test need to be provided
        To set early stopping, provide cutoff (and test sets)
        early_stopping: stop when test loss is lower (or above) the cutoff
        val_stopping: stop when val loss starts to rise   
        denormalize: a tuple (mean, std) for denormalizing target for calculating mse
        info_interval: number of epochs between logging, set to None to turn off console output
        optimize: 'moment' or 'rmsprop'
        test_metric: 'f1'
        window_size: how many values to we average in validation stopping
        """
        assert optimize is None or optimize in ['moment', 'rmsprop'], f"optimize should be None or in ['moment', 'rmsprop']"
        if self.model_type == 'regression':
            test_metric = 'mse'
        
        # setting flags
        test_mse = False
        if X_test is not None and y_test is not None:
            test_mse = True
        early_stopping = False
        if test_mse and cutoff is not None:
            early_stopping = True
            
        test_val = False
        if X_val is not None and y_val is not None:
            test_val = True
        val_stopping = False
        if test_val and val_stopping_k is not None:
            k = val_stopping_k
            val_stopping = True
        
        # resizing
        if resize:
            X = X.to_numpy().reshape(-1, 1)
            y = y.to_numpy().reshape(-1, 1)
            if test_mse:
                X_test = X_test.to_numpy().reshape(-1, 1)
                y_test = y_test.to_numpy().reshape(-1, 1)
            if test_val:
                X_val = X_val.to_numpy().reshape(-1, 1)
                y_val = y_val.to_numpy().reshape(-1, 1)
            
        if batch_size is None:
            batch_size = len(X)
        
        # denormalizing for testing
        y_mse = y
        if denormalize is not None:
            y_mse = destandardize_data(y, denormalize)
            
        history = History()
        
        for epoch in range(1, epochs+1):
            
            # mini batch
            if batch_size < len(X):
                batches_x, batches_y = self.create_batches(X, y, batch_size)
                for i in range(len(batches_x)):
                    self.update_weights(batches_x[i], batches_y[i], learning_rate, optimize, optimize_param, l2_lambda)
            else:
                self.update_weights(X, y, learning_rate, optimize, optimize_param, l2_lambda)
            
            # logging
            if info_interval is not None and epoch % info_interval == 0:
                loss = self.loss(X, y_mse, denormalize=denormalize)
                history.loss.append(loss)
                history.loss_epochs.append(epoch)
                training_info = f"Epoch {epoch}: Loss = {round(loss, 3)}"
                if test_mse:
                    if test_metric == 'f1':
                        loss_test = self.loss(X_test, y_test, denormalize=denormalize, test=True)   
                        history.test_loss.append(loss_test)
                        training_info += f" F1 score = {round(loss_test, 3)}"
                    else:
                        loss_test = self.loss(X_test, y_test, denormalize=denormalize)   
                        history.test_loss.append(loss_test)
                        training_info += f" test loss = {round(loss_test, 3)}"
                if test_val:
                    loss_val = self.loss(X_val, y_val, denormalize=denormalize)
                    history.val_loss.append(loss_val)
                    training_info += f" Val loss = {round(loss_val, 3)}"
                if not mute_print:
                    print(training_info)
            
            history.weights.append(copy.deepcopy(self.weights))
            history.biases.append(copy.deepcopy(self.biases))
            
            if val_stopping:
                loss_val = self.loss(X_val, y_val, denormalize=denormalize)   
                if info_interval is not None and epoch % info_interval != 0:
                    history.val_loss.append(loss_val)
                if len(history.val_loss) > k * window_size:
                    
                    if window_size > 1:
                        averages = [sum(history.val_loss[i:i+window_size]) / window_size for i in range(0, len(history.val_loss) - window_size + 1, window_size)]
                        last_k_averages = averages[-k:]
                        if all(last_k_averages[i] < last_k_averages[i+1] for i in range(k-1)):
                            print(f'validation stopping: {loss_val}')
                            print(last_k_averages)
                            break
                    else:
                        last_k_losses = history.val_loss[-k:]
                        if all(last_k_losses[i] < last_k_losses[i+1] for i in range(k-1)):
                            print(f'validation stopping: {loss_val}')
                            break
            # early stopping
            elif early_stopping:
                loss_es = self.loss(X_test, y_test, denormalize=denormalize, test=True)
                if (loss_es <= cutoff and not cutoff_inverse) or (loss_es >= cutoff and cutoff_inverse):
                    loss = self.loss(X, y_mse, denormalize=denormalize)    
                    training_info = f"Epoch {epoch}: Loss = {round(loss, 3)}"
                    training_info += f" Test loss = {round(loss_es, 3)}"
                    print(training_info)
                    break
                
            
        if return_history:
            history.model_type = self.model_type
            return history

def standardize_data(X):
    """
    returns:
    X_new - standardized X
    a tuple (mean, std) - normal distribution parameters from X for destandarizing
    """
    mean = np.mean(X, axis=0)
    std = np.std(X, axis=0)
    X_new = (X - mean) / std
    return X_new, (mean, std)

def destandardize_data(X, parameters):
    """parameters: a tuple (mean, std)"""
    return X * parameters[1] + parameters[0]


def label_predictions(y_pred, class_order=None):
    """
    y_pred : 2 dimensional array
    class_order : default [..., 2, 1, 0]
    """
    if class_order is None:
        class_order = np.array(range(len(y_pred[0])))
    max_indices = np.argmax(y_pred, axis=1)
    return class_order[max_indices]

def one_hot_encode(y):
    """ y : pd.Series """
    return pd.get_dummies(y, dtype=int).to_numpy()

def decode_array(array):
    """ decodes one hot encoded array """
    decoded_indices = np.argmax(array, axis=1)
    return decoded_indices.tolist()

def plot_classes(data, colors):
    sns.scatterplot(x=data[:,0], y=data[:,1], hue=colors)

def mse(y_true, y_pred):
    """ calculated mse """
    return np.mean((y_pred - y_true) ** 2)

def cross_entropy(y_true, y_pred):
    """ calculates cross entropy loss, y_true and y_pred should be 2-dimensional """
    return -np.mean(np.sum(y_true * np.log(y_pred), axis=1))
    
class History:
    """
    Class which attributes are weights from all training epochs 
    and loss for chosen loss_epochs (usually epochs with some interval)
    """
    
    def __init__(self):
        self.weights = []
        self.biases = []
        self.loss = []
        self.test_loss = []
        self.loss_epochs = []
        self.val_loss = []
        self.model_type = 'regression'
    
    def plot_weights(self, layer, bias=False, return_plot=False):
        """
        layer - integer, index of weights vector
        if to plot bias instead of weights 
        """
        weights = []
        weights_type = 'Weights'
        if bias:
            weights_type = 'Biases'
            for epoch in self.biases:
                weights.append(epoch[layer].flatten())
        else:
            for epoch in self.weights:
                weights.append(epoch[layer].flatten())

        weights = np.array(weights)
        for i in range(weights.shape[1]):
            w_y = weights[:,i]
            plt.plot(range(len(self.weights)), w_y)
            
        plt.xlabel('Epochs')
        plt.title(f'{weights_type} values vs epochs at layer {layer}')
        if return_plot:
            return plt
        else:
            plt.show()
        
    def plot_loss(self, loss_type='train', return_plot=False, settings=''):
        """
        loss_type: 'train', 'test', 'val'
        """
        if loss_type=='test':
            plt.plot(self.loss_epochs, self.test_loss, settings)
            plt.title('Test loss history')
        elif loss_type=='train':
            plt.plot(self.loss_epochs, self.loss, settings)
            plt.title('Training loss history')
        elif loss_type == 'val':
            if len(self.val_loss) > len(self.loss_epochs):
                plt.plot(list(range(len(self.val_loss))), self.val_loss, settings)
            else:
                plt.plot(self.loss_epochs, self.val_loss, settings)
            plt.title('Validation loss history')
        plt.xlabel('Epochs')
        if self.model_type == 'classification':
            plt.ylabel('Cross Entropy')
        else: 
            plt.ylabel('MSE')
        if return_plot:
            return plt
        else:
            plt.show()

# %% [markdown]
# ## Eksperymenty

# %%
from matplotlib.patches import Patch
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### rings 3

# %%
rings3_test = pd.read_csv("../dane/classification/rings3-balance-test.csv")
rings3_train = pd.read_csv("../dane/classification/rings3-balance-training.csv")

# %%
X_train = rings3_train[['x', 'y']].to_numpy()
y_train = one_hot_encode(rings3_train['c'])
X_val, X_test, y_val, y_test = train_test_split(rings3_test[['x', 'y']].to_numpy(), one_hot_encode(rings3_test['c']),
                                                test_size=0.5, random_state=42)
X_train3, _ = standardize_data(X_train)
X_test3, _ = standardize_data(X_test)
X_val3, _ = standardize_data(X_val)

# %% [markdown]
# - Default model

# %%
nn3 = NeuralNetwork([2,10,10,3], model_type='classification')
history3 = nn3.train(X_train3, y_train, learning_rate=0.01, info_interval=100, epochs=10000, batch_size=50,
    X_test=X_test3, y_test=y_test, optimize='moment', return_history=True, X_val=X_val3, y_val=y_val)
# Out:
# Epoch 100: Loss = 0.648 F1 score = 0.344 Val loss = 1.748
# Epoch 200: Loss = 0.641 F1 score = 0.346 Val loss = 1.73
# Epoch 300: Loss = 0.626 F1 score = 0.385 Val loss = 1.679
# Epoch 400: Loss = 0.52 F1 score = 0.413 Val loss = 1.637
# Epoch 500: Loss = 0.216 F1 score = 0.47 Val loss = 1.34
# Epoch 600: Loss = 0.175 F1 score = 0.585 Val loss = 1.146
# Epoch 700: Loss = 0.148 F1 score = 0.617 Val loss = 1.107
# Epoch 800: Loss = 0.136 F1 score = 0.639 Val loss = 1.065
# Epoch 900: Loss = 0.129 F1 score = 0.658 Val loss = 0.991
# Epoch 1000: Loss = 0.119 F1 score = 0.659 Val loss = 0.991
# Epoch 1100: Loss = 0.114 F1 score = 0.675 Val loss = 0.911
# Epoch 1200: Loss = 0.104 F1 score = 0.677 Val loss = 0.873
# Epoch 1300: Loss = 0.095 F1 score = 0.7 Val loss = 0.813
# Epoch 1400: Loss = 0.089 F1 score = 0.709 Val loss = 0.76
# Epoch 1500: Loss = 0.086 F1 score = 0.713 Val loss = 0.786
# Epoch 1600: Loss = 0.078 F1 score = 0.723 Val loss = 0.729
# Epoch 1700: Loss = 0.074 F1 score = 0.734 Val loss = 0.694
# Epoch 1800: Loss = 0.07 F1 score = 0.735 Val loss = 0.68
# Epoch 1900: Loss = 0.069 F1 score = 0.74 Val loss = 0.685
# Epoch 2000: Loss = 0.084 F1 score = 0.738 Val loss = 0.722
# Epoch 2100: Loss = 0.061 F1 score = 0.747 Val loss = 0.634
# Epoch 2200: Loss = 0.061 F1 score = 0.754 Val loss = 0.645
# Epoch 2300: Loss = 0.053 F1 score = 0.771 Val loss = 0.576
# Epoch 2400: Loss = 0.05 F1 score = 0.786 Val loss = 0.556
# Epoch 2500: Loss = 0.052 F1 score = 0.78 Val loss = 0.585
# Epoch 2600: Loss = 0.045 F1 score = 0.796 Val loss = 0.517
# Epoch 2700: Loss = 0.045 F1 score = 0.798 Val loss = 0.549
# Epoch 2800: Loss = 0.044 F1 score = 0.821 Val loss = 0.503
# Epoch 2900: Loss = 0.04 F1 score = 0.816 Val loss = 0.499
# Epoch 3000: Loss = 0.061 F1 score = 0.844 Val loss = 0.492
# Epoch 3100: Loss = 0.043 F1 score = 0.84 Val loss = 0.49
# Epoch 3200: Loss = 0.064 F1 score = 0.805 Val loss = 0.657
# Epoch 3300: Loss = 0.033 F1 score = 0.825 Val loss = 0.524
# Epoch 3400: Loss = 0.038 F1 score = 0.844 Val loss = 0.482
# Epoch 3500: Loss = 0.04 F1 score = 0.844 Val loss = 0.489
# Epoch 3600: Loss = 0.033 F1 score = 0.843 Val loss = 0.519
# Epoch 3700: Loss = 0.03 F1 score = 0.841 Val loss = 0.507
# Epoch 3800: Loss = 0.034 F1 score = 0.839 Val loss = 0.534
# Epoch 3900: Loss = 0.031 F1 score = 0.836 Val loss = 0.561
# Epoch 4000: Loss = 0.034 F1 score = 0.849 Val loss = 0.497
# Epoch 4100: Loss = 0.033 F1 score = 0.843 Val loss = 0.525
# Epoch 4200: Loss = 0.029 F1 score = 0.839 Val loss = 0.528
# Epoch 4300: Loss = 0.037 F1 score = 0.853 Val loss = 0.513
# Epoch 4400: Loss = 0.038 F1 score = 0.857 Val loss = 0.526
# Epoch 4500: Loss = 0.027 F1 score = 0.852 Val loss = 0.545
# Epoch 4600: Loss = 0.027 F1 score = 0.857 Val loss = 0.529
# Epoch 4700: Loss = 0.035 F1 score = 0.859 Val loss = 0.512
# Epoch 4800: Loss = 0.028 F1 score = 0.85 Val loss = 0.605
# Epoch 4900: Loss = 0.027 F1 score = 0.845 Val loss = 0.586
# Epoch 5000: Loss = 0.026 F1 score = 0.86 Val loss = 0.56
# Epoch 5100: Loss = 0.03 F1 score = 0.856 Val loss = 0.544
# Epoch 5200: Loss = 0.026 F1 score = 0.843 Val loss = 0.631
# Epoch 5300: Loss = 0.025 F1 score = 0.849 Val loss = 0.626
# Epoch 5400: Loss = 0.056 F1 score = 0.827 Val loss = 0.748
# Epoch 5500: Loss = 0.027 F1 score = 0.86 Val loss = 0.568
# Epoch 5600: Loss = 0.036 F1 score = 0.836 Val loss = 0.69
# Epoch 5700: Loss = 0.022 F1 score = 0.861 Val loss = 0.6
# Epoch 5800: Loss = 0.022 F1 score = 0.866 Val loss = 0.63
# Epoch 5900: Loss = 0.024 F1 score = 0.86 Val loss = 0.599
# Epoch 6000: Loss = 0.021 F1 score = 0.868 Val loss = 0.605
# Epoch 6100: Loss = 0.022 F1 score = 0.868 Val loss = 0.583
# Epoch 6200: Loss = 0.022 F1 score = 0.857 Val loss = 0.623
# Epoch 6300: Loss = 0.02 F1 score = 0.861 Val loss = 0.646
# Epoch 6400: Loss = 0.026 F1 score = 0.861 Val loss = 0.621
# Epoch 6500: Loss = 0.02 F1 score = 0.87 Val loss = 0.636
# Epoch 6600: Loss = 0.02 F1 score = 0.867 Val loss = 0.664
# Epoch 6700: Loss = 0.033 F1 score = 0.855 Val loss = 0.74
# Epoch 6800: Loss = 0.021 F1 score = 0.866 Val loss = 0.703
# Epoch 6900: Loss = 0.034 F1 score = 0.864 Val loss = 0.768
# Epoch 7000: Loss = 0.026 F1 score = 0.875 Val loss = 0.602
# Epoch 7100: Loss = 0.021 F1 score = 0.872 Val loss = 0.641
# Epoch 7200: Loss = 0.04 F1 score = 0.879 Val loss = 0.59
# Epoch 7300: Loss = 0.02 F1 score = 0.876 Val loss = 0.634
# Epoch 7400: Loss = 0.018 F1 score = 0.873 Val loss = 0.673
# Epoch 7500: Loss = 0.02 F1 score = 0.862 Val loss = 0.735
# Epoch 7600: Loss = 0.029 F1 score = 0.871 Val loss = 0.631
# Epoch 7700: Loss = 0.022 F1 score = 0.874 Val loss = 0.663
# Epoch 7800: Loss = 0.037 F1 score = 0.881 Val loss = 0.599
# Epoch 7900: Loss = 0.03 F1 score = 0.865 Val loss = 0.762
# Epoch 8000: Loss = 0.018 F1 score = 0.87 Val loss = 0.71
# Epoch 8100: Loss = 0.02 F1 score = 0.873 Val loss = 0.721
# Epoch 8200: Loss = 0.02 F1 score = 0.866 Val loss = 0.77
# Epoch 8300: Loss = 0.02 F1 score = 0.863 Val loss = 0.719
# Epoch 8400: Loss = 0.019 F1 score = 0.877 Val loss = 0.683
# Epoch 8500: Loss = 0.018 F1 score = 0.876 Val loss = 0.729
# Epoch 8600: Loss = 0.019 F1 score = 0.871 Val loss = 0.732
# Epoch 8700: Loss = 0.026 F1 score = 0.876 Val loss = 0.681
# Epoch 8800: Loss = 0.021 F1 score = 0.878 Val loss = 0.67
# Epoch 8900: Loss = 0.018 F1 score = 0.875 Val loss = 0.731
# Epoch 9000: Loss = 0.017 F1 score = 0.874 Val loss = 0.724
# Epoch 9100: Loss = 0.023 F1 score = 0.87 Val loss = 0.798
# Epoch 9200: Loss = 0.018 F1 score = 0.866 Val loss = 0.785
# Epoch 9300: Loss = 0.021 F1 score = 0.858 Val loss = 0.806
# Epoch 9400: Loss = 0.019 F1 score = 0.873 Val loss = 0.729
# Epoch 9500: Loss = 0.02 F1 score = 0.873 Val loss = 0.731
# Epoch 9600: Loss = 0.016 F1 score = 0.875 Val loss = 0.741
# Epoch 9700: Loss = 0.02 F1 score = 0.878 Val loss = 0.701
# Epoch 9800: Loss = 0.025 F1 score = 0.873 Val loss = 0.818
# Epoch 9900: Loss = 0.018 F1 score = 0.88 Val loss = 0.714
# Epoch 10000: Loss = 0.019 F1 score = 0.876 Val loss = 0.74

# %%
plt.figure(figsize=(12,4))
plt.subplot(1, 3, 1)
history3.plot_loss(loss_type='train', return_plot=True)
plt.subplot(1, 3, 2)
history3.plot_loss(loss_type='test', return_plot=True)
plt.title('Test f1 score')
plt.ylabel('F1 score')
plt.subplot(1, 3, 3)
history3.plot_loss(loss_type='val', return_plot=True)
plt.title('Validation loss history')
plt.xlabel('Epochs * 100')
plt.tight_layout()
plt.show()
print(f"final f1 score: {round(nn3.f1_score(X_test3, y_test), 3)}")
# Out:
# final f1 score: 0.876

# %%
# Widzimy, że po około 6500 epokach f1 score przestaje wzrastać, z kolei funkcja straty na zbiorze walidacyjnym zaczyna wzrastać już od około 4000 epoki

# %% [markdown]
# - Validation early stopping

# %%
nn3_val = NeuralNetwork([2,10,10,3], model_type='classification')
history3_val = nn3_val.train(X_train3, y_train, learning_rate=0.01, info_interval=100, epochs=10000, batch_size=50,
    X_test=X_test3, y_test=y_test, optimize='moment', return_history=True, X_val=X_val3, y_val=y_val, window_size=5, val_stopping_k=5)
# Out:
# Epoch 100: Loss = 0.642 F1 score = 0.369 Val loss = 1.708
# Epoch 200: Loss = 0.615 F1 score = 0.376 Val loss = 1.694
# Epoch 300: Loss = 0.552 F1 score = 0.399 Val loss = 1.632
# Epoch 400: Loss = 0.248 F1 score = 0.469 Val loss = 1.537
# Epoch 500: Loss = 0.178 F1 score = 0.481 Val loss = 1.217
# Epoch 600: Loss = 0.154 F1 score = 0.535 Val loss = 1.087
# Epoch 700: Loss = 0.135 F1 score = 0.583 Val loss = 1.025
# Epoch 800: Loss = 0.123 F1 score = 0.608 Val loss = 0.979
# Epoch 900: Loss = 0.111 F1 score = 0.641 Val loss = 0.896
# Epoch 1000: Loss = 0.1 F1 score = 0.655 Val loss = 0.847
# Epoch 1100: Loss = 0.093 F1 score = 0.673 Val loss = 0.797
# Epoch 1200: Loss = 0.084 F1 score = 0.692 Val loss = 0.726
# Epoch 1300: Loss = 0.078 F1 score = 0.712 Val loss = 0.699
# Epoch 1400: Loss = 0.073 F1 score = 0.731 Val loss = 0.67
# Epoch 1500: Loss = 0.069 F1 score = 0.753 Val loss = 0.612
# Epoch 1600: Loss = 0.066 F1 score = 0.764 Val loss = 0.59
# Epoch 1700: Loss = 0.066 F1 score = 0.76 Val loss = 0.608
# Epoch 1800: Loss = 0.06 F1 score = 0.774 Val loss = 0.575
# Epoch 1900: Loss = 0.056 F1 score = 0.783 Val loss = 0.546
# Epoch 2000: Loss = 0.054 F1 score = 0.793 Val loss = 0.528
# Epoch 2100: Loss = 0.055 F1 score = 0.799 Val loss = 0.52
# Epoch 2200: Loss = 0.052 F1 score = 0.81 Val loss = 0.494
# Epoch 2300: Loss = 0.047 F1 score = 0.815 Val loss = 0.49
# Epoch 2400: Loss = 0.046 F1 score = 0.81 Val loss = 0.509
# Epoch 2500: Loss = 0.051 F1 score = 0.824 Val loss = 0.47
# Epoch 2600: Loss = 0.042 F1 score = 0.83 Val loss = 0.467
# Epoch 2700: Loss = 0.041 F1 score = 0.832 Val loss = 0.478
# Epoch 2800: Loss = 0.042 F1 score = 0.839 Val loss = 0.458
# Epoch 2900: Loss = 0.039 F1 score = 0.846 Val loss = 0.462
# Epoch 3000: Loss = 0.037 F1 score = 0.849 Val loss = 0.458
# Epoch 3100: Loss = 0.037 F1 score = 0.839 Val loss = 0.483
# Epoch 3200: Loss = 0.034 F1 score = 0.855 Val loss = 0.46
# Epoch 3300: Loss = 0.035 F1 score = 0.854 Val loss = 0.473
# Epoch 3400: Loss = 0.033 F1 score = 0.85 Val loss = 0.464
# Epoch 3500: Loss = 0.033 F1 score = 0.856 Val loss = 0.459
# Epoch 3600: Loss = 0.031 F1 score = 0.856 Val loss = 0.46
# Epoch 3700: Loss = 0.029 F1 score = 0.856 Val loss = 0.454
# Epoch 3800: Loss = 0.029 F1 score = 0.861 Val loss = 0.45
# Epoch 3900: Loss = 0.035 F1 score = 0.868 Val loss = 0.406
# Epoch 4000: Loss = 0.029 F1 score = 0.868 Val loss = 0.422
# Epoch 4100: Loss = 0.026 F1 score = 0.869 Val loss = 0.445
# Epoch 4200: Loss = 0.026 F1 score = 0.869 Val loss = 0.423
# Epoch 4300: Loss = 0.026 F1 score = 0.869 Val loss = 0.434
# Epoch 4400: Loss = 0.025 F1 score = 0.869 Val loss = 0.434
# Epoch 4500: Loss = 0.023 F1 score = 0.873 Val loss = 0.424
# Epoch 4600: Loss = 0.023 F1 score = 0.872 Val loss = 0.422
# Epoch 4700: Loss = 0.029 F1 score = 0.874 Val loss = 0.426
# Epoch 4800: Loss = 0.022 F1 score = 0.875 Val loss = 0.437
# Epoch 4900: Loss = 0.021 F1 score = 0.874 Val loss = 0.442
# Epoch 5000: Loss = 0.022 F1 score = 0.873 Val loss = 0.455
# Epoch 5100: Loss = 0.026 F1 score = 0.879 Val loss = 0.429
# validation stopping: 0.4142847206470956
# [0.4327931341631087, 0.4355459015345396, 0.44050971822008655, 0.4455204081689395, 0.44967687717893157]

# %%
plt.figure(figsize=(12,4))
plt.subplot(1, 3, 1)
history3_val.plot_loss(loss_type='train', return_plot=True, settings='r')
plt.subplot(1, 3, 2)
history3_val.plot_loss(loss_type='test', return_plot=True, settings='r')
plt.title('Test f1 score')
plt.ylabel('F1 score')
plt.subplot(1, 3, 3)
history3_val.plot_loss(loss_type='val', return_plot=True, settings='r')
plt.title('Validation loss history')
plt.tight_layout()
plt.show()
print(f"final f1 score: {round(nn3_val.f1_score(X_test3, y_test), 3)}")
# Out:
# final f1 score: 0.879

# %%
# f1 score jest w zasadzie identyczny, jak w przypadku treningu bez early stoppingu, jednakże uzyskaliśmy ten wynik bez zbędnego dodatkowego treningu kilku tysięcy epok

# %% [markdown]
# - Regularization

# %%
nn3_reg = NeuralNetwork([2,10,10,3], model_type='classification')
history3_reg = nn3_reg.train(X_train3, y_train, learning_rate=0.01, info_interval=100, epochs=10000, batch_size=50, l2_lambda=0.001,
    X_test=X_test3, y_test=y_test, optimize='moment', return_history=True, X_val=X_val3, y_val=y_val)
# Out:
# Epoch 100: Loss = 0.647 F1 score = 0.347 Val loss = 1.748
# Epoch 200: Loss = 0.647 F1 score = 0.345 Val loss = 1.752
# Epoch 300: Loss = 0.509 F1 score = 0.417 Val loss = 1.639
# Epoch 400: Loss = 0.446 F1 score = 0.42 Val loss = 1.582
# Epoch 500: Loss = 0.221 F1 score = 0.469 Val loss = 1.3
# Epoch 600: Loss = 0.169 F1 score = 0.58 Val loss = 1.084
# Epoch 700: Loss = 0.144 F1 score = 0.619 Val loss = 0.99
# Epoch 800: Loss = 0.12 F1 score = 0.637 Val loss = 0.95
# Epoch 900: Loss = 0.108 F1 score = 0.66 Val loss = 0.903
# Epoch 1000: Loss = 0.101 F1 score = 0.695 Val loss = 0.798
# Epoch 1100: Loss = 0.089 F1 score = 0.705 Val loss = 0.762
# Epoch 1200: Loss = 0.081 F1 score = 0.714 Val loss = 0.709
# Epoch 1300: Loss = 0.074 F1 score = 0.734 Val loss = 0.62
# Epoch 1400: Loss = 0.07 F1 score = 0.751 Val loss = 0.581
# Epoch 1500: Loss = 0.072 F1 score = 0.762 Val loss = 0.586
# Epoch 1600: Loss = 0.06 F1 score = 0.783 Val loss = 0.551
# Epoch 1700: Loss = 0.056 F1 score = 0.8 Val loss = 0.506
# Epoch 1800: Loss = 0.054 F1 score = 0.795 Val loss = 0.511
# Epoch 1900: Loss = 0.052 F1 score = 0.81 Val loss = 0.485
# Epoch 2000: Loss = 0.048 F1 score = 0.805 Val loss = 0.491
# Epoch 2100: Loss = 0.046 F1 score = 0.83 Val loss = 0.435
# Epoch 2200: Loss = 0.046 F1 score = 0.832 Val loss = 0.449
# Epoch 2300: Loss = 0.041 F1 score = 0.827 Val loss = 0.453
# Epoch 2400: Loss = 0.04 F1 score = 0.828 Val loss = 0.467
# Epoch 2500: Loss = 0.041 F1 score = 0.843 Val loss = 0.407
# Epoch 2600: Loss = 0.04 F1 score = 0.841 Val loss = 0.436
# Epoch 2700: Loss = 0.039 F1 score = 0.841 Val loss = 0.422
# Epoch 2800: Loss = 0.048 F1 score = 0.847 Val loss = 0.403
# Epoch 2900: Loss = 0.034 F1 score = 0.847 Val loss = 0.424
# Epoch 3000: Loss = 0.04 F1 score = 0.842 Val loss = 0.434
# Epoch 3100: Loss = 0.034 F1 score = 0.846 Val loss = 0.42
# Epoch 3200: Loss = 0.031 F1 score = 0.848 Val loss = 0.47
# Epoch 3300: Loss = 0.03 F1 score = 0.843 Val loss = 0.465
# Epoch 3400: Loss = 0.029 F1 score = 0.856 Val loss = 0.454
# Epoch 3500: Loss = 0.031 F1 score = 0.851 Val loss = 0.475
# Epoch 3600: Loss = 0.067 F1 score = 0.859 Val loss = 0.433
# Epoch 3700: Loss = 0.038 F1 score = 0.846 Val loss = 0.518
# Epoch 3800: Loss = 0.027 F1 score = 0.845 Val loss = 0.498
# Epoch 3900: Loss = 0.03 F1 score = 0.849 Val loss = 0.501
# Epoch 4000: Loss = 0.026 F1 score = 0.854 Val loss = 0.497
# Epoch 4100: Loss = 0.03 F1 score = 0.845 Val loss = 0.525
# Epoch 4200: Loss = 0.025 F1 score = 0.864 Val loss = 0.454
# Epoch 4300: Loss = 0.027 F1 score = 0.865 Val loss = 0.448
# Epoch 4400: Loss = 0.046 F1 score = 0.858 Val loss = 0.449
# Epoch 4500: Loss = 0.026 F1 score = 0.863 Val loss = 0.454
# Epoch 4600: Loss = 0.026 F1 score = 0.852 Val loss = 0.497
# Epoch 4700: Loss = 0.027 F1 score = 0.861 Val loss = 0.446
# Epoch 4800: Loss = 0.03 F1 score = 0.85 Val loss = 0.521
# Epoch 4900: Loss = 0.034 F1 score = 0.863 Val loss = 0.432
# Epoch 5000: Loss = 0.029 F1 score = 0.876 Val loss = 0.422
# Epoch 5100: Loss = 0.024 F1 score = 0.86 Val loss = 0.48
# Epoch 5200: Loss = 0.023 F1 score = 0.866 Val loss = 0.451
# Epoch 5300: Loss = 0.023 F1 score = 0.866 Val loss = 0.462
# Epoch 5400: Loss = 0.025 F1 score = 0.865 Val loss = 0.475
# Epoch 5500: Loss = 0.021 F1 score = 0.869 Val loss = 0.474
# Epoch 5600: Loss = 0.026 F1 score = 0.876 Val loss = 0.448
# Epoch 5700: Loss = 0.021 F1 score = 0.869 Val loss = 0.487
# Epoch 5800: Loss = 0.025 F1 score = 0.863 Val loss = 0.513
# Epoch 5900: Loss = 0.02 F1 score = 0.875 Val loss = 0.462
# Epoch 6000: Loss = 0.026 F1 score = 0.869 Val loss = 0.501
# Epoch 6100: Loss = 0.028 F1 score = 0.862 Val loss = 0.535
# Epoch 6200: Loss = 0.02 F1 score = 0.87 Val loss = 0.487
# Epoch 6300: Loss = 0.021 F1 score = 0.876 Val loss = 0.473
# Epoch 6400: Loss = 0.02 F1 score = 0.867 Val loss = 0.515
# Epoch 6500: Loss = 0.023 F1 score = 0.871 Val loss = 0.481
# Epoch 6600: Loss = 0.025 F1 score = 0.871 Val loss = 0.502
# Epoch 6700: Loss = 0.025 F1 score = 0.863 Val loss = 0.545
# Epoch 6800: Loss = 0.019 F1 score = 0.874 Val loss = 0.503
# Epoch 6900: Loss = 0.037 F1 score = 0.88 Val loss = 0.472
# Epoch 7000: Loss = 0.021 F1 score = 0.873 Val loss = 0.523
# Epoch 7100: Loss = 0.021 F1 score = 0.872 Val loss = 0.505
# Epoch 7200: Loss = 0.045 F1 score = 0.863 Val loss = 0.59
# Epoch 7300: Loss = 0.019 F1 score = 0.869 Val loss = 0.537
# Epoch 7400: Loss = 0.035 F1 score = 0.859 Val loss = 0.593
# Epoch 7500: Loss = 0.027 F1 score = 0.866 Val loss = 0.565
# Epoch 7600: Loss = 0.018 F1 score = 0.876 Val loss = 0.521
# Epoch 7700: Loss = 0.021 F1 score = 0.869 Val loss = 0.557
# Epoch 7800: Loss = 0.021 F1 score = 0.866 Val loss = 0.556
# Epoch 7900: Loss = 0.017 F1 score = 0.874 Val loss = 0.531
# Epoch 8000: Loss = 0.017 F1 score = 0.873 Val loss = 0.539
# Epoch 8100: Loss = 0.018 F1 score = 0.876 Val loss = 0.525
# Epoch 8200: Loss = 0.017 F1 score = 0.874 Val loss = 0.528
# Epoch 8300: Loss = 0.017 F1 score = 0.874 Val loss = 0.55
# Epoch 8400: Loss = 0.021 F1 score = 0.886 Val loss = 0.489
# Epoch 8500: Loss = 0.019 F1 score = 0.875 Val loss = 0.561
# Epoch 8600: Loss = 0.021 F1 score = 0.878 Val loss = 0.511
# Epoch 8700: Loss = 0.029 F1 score = 0.865 Val loss = 0.591
# Epoch 8800: Loss = 0.021 F1 score = 0.885 Val loss = 0.5
# Epoch 8900: Loss = 0.037 F1 score = 0.873 Val loss = 0.573
# Epoch 9000: Loss = 0.016 F1 score = 0.881 Val loss = 0.537
# Epoch 9100: Loss = 0.017 F1 score = 0.88 Val loss = 0.539
# Epoch 9200: Loss = 0.016 F1 score = 0.878 Val loss = 0.547
# Epoch 9300: Loss = 0.023 F1 score = 0.886 Val loss = 0.495
# Epoch 9400: Loss = 0.018 F1 score = 0.885 Val loss = 0.497
# Epoch 9500: Loss = 0.017 F1 score = 0.88 Val loss = 0.546
# Epoch 9600: Loss = 0.015 F1 score = 0.878 Val loss = 0.531
# Epoch 9700: Loss = 0.016 F1 score = 0.881 Val loss = 0.553
# Epoch 9800: Loss = 0.015 F1 score = 0.878 Val loss = 0.553
# Epoch 9900: Loss = 0.016 F1 score = 0.883 Val loss = 0.503
# Epoch 10000: Loss = 0.021 F1 score = 0.884 Val loss = 0.519

# %%
plt.figure(figsize=(12,4))
plt.subplot(1, 3, 1)
history3_reg.plot_loss(loss_type='train', return_plot=True, settings='y')
plt.subplot(1, 3, 2)
history3_reg.plot_loss(loss_type='test', return_plot=True, settings='y')
plt.title('Test f1 score')
plt.ylabel('F1 score')
plt.subplot(1, 3, 3)
history3_reg.plot_loss(loss_type='val', return_plot=True, settings='y')
plt.title('Validation loss history')
plt.tight_layout()
plt.show()
print(f"final f1 score: {round(nn3_reg.f1_score(X_test3, y_test), 3)}")
# Out:
# final f1 score: 0.884

# %%
# Wykresy metryk wyglądają w zasadzie identycznie jak bez regularyzacji. Zobaczmy jak wygląda podział klas:

# %%
plt.figure(figsize=(14,4))
plt.subplot(1,3,1)
nn3.plot_classes(X_test3)
plt.title('no regularization')
plt.subplot(1,3,2)
nn3_reg.plot_classes(X_test3)
plt.title('with regularization')
plt.subplot(1,3,3)
plot_classes(X_test3, decode_array(y_test))
plt.title('test')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.subplot(1, 2, 1)
history3.plot_weights(0, return_plot=True)
plt.title("Weights values at layer 0, no regularization")
plt.subplot(1, 2, 2)
history3_reg.plot_weights(0, return_plot=True)
plt.title("Weights values at layer 0, with regularization")
plt.tight_layout()
plt.show()

# %%
# Widzimy, że bez regularyzacji duża część wag pozostaje bardzo bliska zeru. W przypadku regularyzacji nie ma takowych, najprawdopobniej przez to, że zawsze dodajemy odrobinę "szumu".

# %% [markdown]
# ### rings 5

# %%
rings5_test = pd.read_csv("../dane/classification/rings5-sparse-test.csv")
rings5_train = pd.read_csv("../dane/classification/rings5-sparse-training.csv")

# %%
X_train = rings5_train[['x', 'y']].to_numpy()
y_train = one_hot_encode(rings5_train['c'])
X_val, X_test, y_val, y_test = train_test_split(rings5_test[['x', 'y']].to_numpy(), one_hot_encode(rings5_test['c']),
                                                test_size=0.5, random_state=42)
X_train5, _ = standardize_data(X_train)
X_test5, _ = standardize_data(X_test)
X_val5, _ = standardize_data(X_val)

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.title('train')
plot_classes(X_train5, rings5_train['c'])
plt.subplot(1,2,2)
plt.title('test')
plot_classes(X_test5, decode_array(y_test))

# %% [markdown]
# - Default model

# %%
nn5 = NeuralNetwork([2,10,10,5], model_type='classification')
history5 = nn5.train(X_train5, y_train, learning_rate=0.01, info_interval=100, epochs=10000, batch_size=50,
    X_test=X_test5, y_test=y_test, optimize='moment', return_history=True, X_val=X_val5, y_val=y_val)
# Out:
# Epoch 100: Loss = 1.538 F1 score = 0.222 Val loss = 1.556
# Epoch 200: Loss = 1.366 F1 score = 0.247 Val loss = 1.445
# Epoch 300: Loss = 1.332 F1 score = 0.282 Val loss = 1.421
# Epoch 400: Loss = 1.316 F1 score = 0.315 Val loss = 1.402
# Epoch 500: Loss = 1.293 F1 score = 0.344 Val loss = 1.375
# Epoch 600: Loss = 1.253 F1 score = 0.379 Val loss = 1.331
# Epoch 700: Loss = 1.189 F1 score = 0.402 Val loss = 1.268
# Epoch 800: Loss = 1.115 F1 score = 0.441 Val loss = 1.202
# Epoch 900: Loss = 1.05 F1 score = 0.451 Val loss = 1.147
# Epoch 1000: Loss = 0.998 F1 score = 0.467 Val loss = 1.105
# Epoch 1100: Loss = 0.955 F1 score = 0.497 Val loss = 1.077
# Epoch 1200: Loss = 0.917 F1 score = 0.493 Val loss = 1.058
# Epoch 1300: Loss = 0.882 F1 score = 0.494 Val loss = 1.039
# Epoch 1400: Loss = 0.846 F1 score = 0.497 Val loss = 1.023
# Epoch 1500: Loss = 0.801 F1 score = 0.503 Val loss = 0.996
# Epoch 1600: Loss = 0.744 F1 score = 0.52 Val loss = 0.958
# Epoch 1700: Loss = 0.696 F1 score = 0.576 Val loss = 0.927
# Epoch 1800: Loss = 0.659 F1 score = 0.587 Val loss = 0.902
# Epoch 1900: Loss = 0.629 F1 score = 0.584 Val loss = 0.884
# Epoch 2000: Loss = 0.604 F1 score = 0.587 Val loss = 0.872
# Epoch 2100: Loss = 0.583 F1 score = 0.588 Val loss = 0.862
# Epoch 2200: Loss = 0.563 F1 score = 0.589 Val loss = 0.852
# Epoch 2300: Loss = 0.545 F1 score = 0.586 Val loss = 0.842
# Epoch 2400: Loss = 0.528 F1 score = 0.59 Val loss = 0.832
# Epoch 2500: Loss = 0.512 F1 score = 0.589 Val loss = 0.826
# Epoch 2600: Loss = 0.496 F1 score = 0.591 Val loss = 0.817
# Epoch 2700: Loss = 0.48 F1 score = 0.586 Val loss = 0.81
# Epoch 2800: Loss = 0.463 F1 score = 0.591 Val loss = 0.801
# Epoch 2900: Loss = 0.447 F1 score = 0.59 Val loss = 0.798
# Epoch 3000: Loss = 0.43 F1 score = 0.605 Val loss = 0.787
# Epoch 3100: Loss = 0.413 F1 score = 0.615 Val loss = 0.778
# Epoch 3200: Loss = 0.398 F1 score = 0.621 Val loss = 0.773
# Epoch 3300: Loss = 0.383 F1 score = 0.629 Val loss = 0.762
# Epoch 3400: Loss = 0.369 F1 score = 0.639 Val loss = 0.76
# Epoch 3500: Loss = 0.356 F1 score = 0.645 Val loss = 0.75
# Epoch 3600: Loss = 0.344 F1 score = 0.653 Val loss = 0.742
# Epoch 3700: Loss = 0.333 F1 score = 0.664 Val loss = 0.739
# Epoch 3800: Loss = 0.322 F1 score = 0.667 Val loss = 0.728
# Epoch 3900: Loss = 0.312 F1 score = 0.675 Val loss = 0.724
# Epoch 4000: Loss = 0.302 F1 score = 0.672 Val loss = 0.724
# Epoch 4100: Loss = 0.293 F1 score = 0.673 Val loss = 0.718
# Epoch 4200: Loss = 0.284 F1 score = 0.671 Val loss = 0.716
# Epoch 4300: Loss = 0.276 F1 score = 0.68 Val loss = 0.712
# Epoch 4400: Loss = 0.268 F1 score = 0.686 Val loss = 0.71
# Epoch 4500: Loss = 0.26 F1 score = 0.69 Val loss = 0.71
# Epoch 4600: Loss = 0.253 F1 score = 0.693 Val loss = 0.71
# Epoch 4700: Loss = 0.245 F1 score = 0.69 Val loss = 0.713
# Epoch 4800: Loss = 0.239 F1 score = 0.69 Val loss = 0.717
# Epoch 4900: Loss = 0.232 F1 score = 0.693 Val loss = 0.715
# Epoch 5000: Loss = 0.226 F1 score = 0.698 Val loss = 0.722
# Epoch 5100: Loss = 0.22 F1 score = 0.699 Val loss = 0.728
# Epoch 5200: Loss = 0.215 F1 score = 0.696 Val loss = 0.732
# Epoch 5300: Loss = 0.209 F1 score = 0.703 Val loss = 0.736
# Epoch 5400: Loss = 0.204 F1 score = 0.704 Val loss = 0.737
# Epoch 5500: Loss = 0.2 F1 score = 0.706 Val loss = 0.744
# Epoch 5600: Loss = 0.195 F1 score = 0.707 Val loss = 0.749
# Epoch 5700: Loss = 0.191 F1 score = 0.701 Val loss = 0.759
# Epoch 5800: Loss = 0.186 F1 score = 0.707 Val loss = 0.763
# Epoch 5900: Loss = 0.182 F1 score = 0.71 Val loss = 0.767
# Epoch 6000: Loss = 0.179 F1 score = 0.711 Val loss = 0.774
# Epoch 6100: Loss = 0.175 F1 score = 0.715 Val loss = 0.774
# Epoch 6200: Loss = 0.171 F1 score = 0.712 Val loss = 0.786
# Epoch 6300: Loss = 0.168 F1 score = 0.711 Val loss = 0.787
# Epoch 6400: Loss = 0.165 F1 score = 0.707 Val loss = 0.797
# Epoch 6500: Loss = 0.162 F1 score = 0.706 Val loss = 0.797
# Epoch 6600: Loss = 0.159 F1 score = 0.706 Val loss = 0.804
# Epoch 6700: Loss = 0.156 F1 score = 0.705 Val loss = 0.811
# Epoch 6800: Loss = 0.153 F1 score = 0.705 Val loss = 0.813
# Epoch 6900: Loss = 0.15 F1 score = 0.704 Val loss = 0.821
# Epoch 7000: Loss = 0.147 F1 score = 0.702 Val loss = 0.83
# Epoch 7100: Loss = 0.145 F1 score = 0.706 Val loss = 0.829
# Epoch 7200: Loss = 0.142 F1 score = 0.706 Val loss = 0.832
# Epoch 7300: Loss = 0.14 F1 score = 0.704 Val loss = 0.845
# Epoch 7400: Loss = 0.137 F1 score = 0.705 Val loss = 0.844
# Epoch 7500: Loss = 0.135 F1 score = 0.707 Val loss = 0.85
# Epoch 7600: Loss = 0.133 F1 score = 0.705 Val loss = 0.854
# Epoch 7700: Loss = 0.13 F1 score = 0.703 Val loss = 0.86
# Epoch 7800: Loss = 0.128 F1 score = 0.703 Val loss = 0.864
# Epoch 7900: Loss = 0.126 F1 score = 0.705 Val loss = 0.87
# Epoch 8000: Loss = 0.124 F1 score = 0.701 Val loss = 0.876
# Epoch 8100: Loss = 0.122 F1 score = 0.701 Val loss = 0.882
# Epoch 8200: Loss = 0.12 F1 score = 0.703 Val loss = 0.884
# Epoch 8300: Loss = 0.118 F1 score = 0.707 Val loss = 0.889
# Epoch 8400: Loss = 0.116 F1 score = 0.7 Val loss = 0.902
# Epoch 8500: Loss = 0.114 F1 score = 0.706 Val loss = 0.901
# Epoch 8600: Loss = 0.112 F1 score = 0.704 Val loss = 0.91
# Epoch 8700: Loss = 0.111 F1 score = 0.707 Val loss = 0.913
# Epoch 8800: Loss = 0.109 F1 score = 0.704 Val loss = 0.917
# Epoch 8900: Loss = 0.107 F1 score = 0.703 Val loss = 0.926
# Epoch 9000: Loss = 0.105 F1 score = 0.705 Val loss = 0.927
# Epoch 9100: Loss = 0.104 F1 score = 0.705 Val loss = 0.935
# Epoch 9200: Loss = 0.102 F1 score = 0.706 Val loss = 0.941
# Epoch 9300: Loss = 0.101 F1 score = 0.708 Val loss = 0.944
# Epoch 9400: Loss = 0.099 F1 score = 0.706 Val loss = 0.952
# Epoch 9500: Loss = 0.097 F1 score = 0.705 Val loss = 0.959
# Epoch 9600: Loss = 0.096 F1 score = 0.703 Val loss = 0.965
# Epoch 9700: Loss = 0.095 F1 score = 0.704 Val loss = 0.968
# Epoch 9800: Loss = 0.093 F1 score = 0.705 Val loss = 0.973
# Epoch 9900: Loss = 0.092 F1 score = 0.699 Val loss = 0.985
# Epoch 10000: Loss = 0.09 F1 score = 0.701 Val loss = 0.988

# %%
plt.figure(figsize=(12,4))
plt.subplot(1, 3, 1)
history5.plot_loss(loss_type='train', return_plot=True)
plt.subplot(1, 3, 2)
history5.plot_loss(loss_type='test', return_plot=True)
plt.title('Test f1 score')
plt.ylabel('F1 score')
plt.subplot(1, 3, 3)
history5.plot_loss(loss_type='val', return_plot=True)
plt.tight_layout()
plt.show()
print(f"final f1 score: {round(nn5.f1_score(X_test5, y_test), 3)}")
# Out:
# final f1 score: 0.701

# %% [markdown]
# - Validation early stopping

# %%
nn5_val = NeuralNetwork([2,10,10,5], model_type='classification')
history5_val = nn5_val.train(X_train5, y_train, learning_rate=0.01, info_interval=100, epochs=10000, batch_size=50, val_stopping_k=5, window_size=5,
    X_test=X_test5, y_test=y_test, optimize='moment', return_history=True, X_val=X_val5, y_val=y_val)
# Out:
# Epoch 100: Loss = 1.517 F1 score = 0.185 Val loss = 1.553
# Epoch 200: Loss = 1.359 F1 score = 0.227 Val loss = 1.451
# Epoch 300: Loss = 1.337 F1 score = 0.253 Val loss = 1.429
# Epoch 400: Loss = 1.327 F1 score = 0.286 Val loss = 1.415
# Epoch 500: Loss = 1.314 F1 score = 0.296 Val loss = 1.398
# Epoch 600: Loss = 1.297 F1 score = 0.319 Val loss = 1.378
# Epoch 700: Loss = 1.273 F1 score = 0.364 Val loss = 1.35
# Epoch 800: Loss = 1.234 F1 score = 0.38 Val loss = 1.318
# Epoch 900: Loss = 1.18 F1 score = 0.399 Val loss = 1.279
# Epoch 1000: Loss = 1.12 F1 score = 0.404 Val loss = 1.235
# Epoch 1100: Loss = 1.059 F1 score = 0.412 Val loss = 1.19
# Epoch 1200: Loss = 1.002 F1 score = 0.45 Val loss = 1.15
# Epoch 1300: Loss = 0.951 F1 score = 0.459 Val loss = 1.113
# Epoch 1400: Loss = 0.907 F1 score = 0.457 Val loss = 1.087
# Epoch 1500: Loss = 0.868 F1 score = 0.453 Val loss = 1.062
# Epoch 1600: Loss = 0.832 F1 score = 0.462 Val loss = 1.042
# Epoch 1700: Loss = 0.794 F1 score = 0.469 Val loss = 1.019
# Epoch 1800: Loss = 0.753 F1 score = 0.494 Val loss = 0.987
# Epoch 1900: Loss = 0.709 F1 score = 0.542 Val loss = 0.956
# Epoch 2000: Loss = 0.667 F1 score = 0.562 Val loss = 0.926
# Epoch 2100: Loss = 0.632 F1 score = 0.579 Val loss = 0.905
# Epoch 2200: Loss = 0.603 F1 score = 0.586 Val loss = 0.884
# Epoch 2300: Loss = 0.578 F1 score = 0.585 Val loss = 0.87
# Epoch 2400: Loss = 0.555 F1 score = 0.589 Val loss = 0.858
# Epoch 2500: Loss = 0.534 F1 score = 0.593 Val loss = 0.847
# Epoch 2600: Loss = 0.513 F1 score = 0.591 Val loss = 0.837
# Epoch 2700: Loss = 0.492 F1 score = 0.591 Val loss = 0.823
# Epoch 2800: Loss = 0.47 F1 score = 0.597 Val loss = 0.811
# Epoch 2900: Loss = 0.446 F1 score = 0.605 Val loss = 0.794
# Epoch 3000: Loss = 0.423 F1 score = 0.616 Val loss = 0.779
# Epoch 3100: Loss = 0.401 F1 score = 0.63 Val loss = 0.761
# Epoch 3200: Loss = 0.38 F1 score = 0.638 Val loss = 0.747
# Epoch 3300: Loss = 0.359 F1 score = 0.651 Val loss = 0.729
# Epoch 3400: Loss = 0.34 F1 score = 0.663 Val loss = 0.713
# Epoch 3500: Loss = 0.323 F1 score = 0.676 Val loss = 0.7
# Epoch 3600: Loss = 0.307 F1 score = 0.682 Val loss = 0.689
# Epoch 3700: Loss = 0.292 F1 score = 0.693 Val loss = 0.68
# Epoch 3800: Loss = 0.278 F1 score = 0.697 Val loss = 0.676
# Epoch 3900: Loss = 0.266 F1 score = 0.704 Val loss = 0.67
# Epoch 4000: Loss = 0.255 F1 score = 0.704 Val loss = 0.672
# Epoch 4100: Loss = 0.246 F1 score = 0.711 Val loss = 0.668
# Epoch 4200: Loss = 0.237 F1 score = 0.711 Val loss = 0.668
# Epoch 4300: Loss = 0.228 F1 score = 0.715 Val loss = 0.67
# Epoch 4400: Loss = 0.221 F1 score = 0.717 Val loss = 0.677
# validation stopping: 0.6774197660318527
# [0.6747596641644451, 0.6753566567857391, 0.6772063411132665, 0.6779162615697573, 0.6781305460406447]

# %%
plt.figure(figsize=(12,4))
plt.subplot(1, 3, 1)
history5_val.plot_loss(loss_type='train', return_plot=True, settings='r')
plt.subplot(1, 3, 2)
history5_val.plot_loss(loss_type='test', return_plot=True, settings='r')
plt.title('Test f1 score')
plt.ylabel('F1 score')
plt.subplot(1, 3, 3)
history5_val.plot_loss(loss_type='val', return_plot=True, settings='r')
plt.tight_layout()
plt.show()
print(f"final f1 score: {round(nn5_val.f1_score(X_test5, y_test), 3)}")
# Out:
# final f1 score: 0.717

# %%
# Uzyskaliśmy lepszy f1 score, dzięki temu że zatrzymaliśmy trening odpowiednio wcześnie

# %% [markdown]
# - Regularization

# %%
nn5_reg = NeuralNetwork([2,10,10,5], model_type='classification')
history5_reg = nn5_reg.train(X_train5, y_train, learning_rate=0.01, info_interval=100, epochs=10000, batch_size=50, l2_lambda=0.001,
    X_test=X_test5, y_test=y_test, optimize='moment', return_history=True, X_val=X_val5, y_val=y_val)
# Out:
# Epoch 100: Loss = 1.535 F1 score = 0.134 Val loss = 1.568
# Epoch 200: Loss = 1.365 F1 score = 0.237 Val loss = 1.458
# Epoch 300: Loss = 1.334 F1 score = 0.289 Val loss = 1.43
# Epoch 400: Loss = 1.319 F1 score = 0.324 Val loss = 1.41
# Epoch 500: Loss = 1.297 F1 score = 0.346 Val loss = 1.386
# Epoch 600: Loss = 1.258 F1 score = 0.379 Val loss = 1.343
# Epoch 700: Loss = 1.196 F1 score = 0.393 Val loss = 1.286
# Epoch 800: Loss = 1.113 F1 score = 0.419 Val loss = 1.219
# Epoch 900: Loss = 1.033 F1 score = 0.434 Val loss = 1.157
# Epoch 1000: Loss = 0.969 F1 score = 0.475 Val loss = 1.113
# Epoch 1100: Loss = 0.919 F1 score = 0.469 Val loss = 1.077
# Epoch 1200: Loss = 0.877 F1 score = 0.461 Val loss = 1.057
# Epoch 1300: Loss = 0.841 F1 score = 0.464 Val loss = 1.036
# Epoch 1400: Loss = 0.808 F1 score = 0.47 Val loss = 1.019
# Epoch 1500: Loss = 0.774 F1 score = 0.479 Val loss = 1.001
# Epoch 1600: Loss = 0.739 F1 score = 0.479 Val loss = 0.978
# Epoch 1700: Loss = 0.704 F1 score = 0.485 Val loss = 0.956
# Epoch 1800: Loss = 0.671 F1 score = 0.509 Val loss = 0.932
# Epoch 1900: Loss = 0.639 F1 score = 0.522 Val loss = 0.908
# Epoch 2000: Loss = 0.609 F1 score = 0.549 Val loss = 0.883
# Epoch 2100: Loss = 0.578 F1 score = 0.578 Val loss = 0.857
# Epoch 2200: Loss = 0.548 F1 score = 0.593 Val loss = 0.832
# Epoch 2300: Loss = 0.519 F1 score = 0.599 Val loss = 0.808
# Epoch 2400: Loss = 0.492 F1 score = 0.603 Val loss = 0.792
# Epoch 2500: Loss = 0.467 F1 score = 0.61 Val loss = 0.777
# Epoch 2600: Loss = 0.446 F1 score = 0.611 Val loss = 0.767
# Epoch 2700: Loss = 0.426 F1 score = 0.619 Val loss = 0.757
# Epoch 2800: Loss = 0.408 F1 score = 0.625 Val loss = 0.746
# Epoch 2900: Loss = 0.391 F1 score = 0.623 Val loss = 0.74
# Epoch 3000: Loss = 0.376 F1 score = 0.627 Val loss = 0.733
# Epoch 3100: Loss = 0.362 F1 score = 0.632 Val loss = 0.726
# Epoch 3200: Loss = 0.349 F1 score = 0.641 Val loss = 0.721
# Epoch 3300: Loss = 0.336 F1 score = 0.648 Val loss = 0.718
# Epoch 3400: Loss = 0.325 F1 score = 0.65 Val loss = 0.716
# Epoch 3500: Loss = 0.313 F1 score = 0.662 Val loss = 0.709
# Epoch 3600: Loss = 0.303 F1 score = 0.66 Val loss = 0.711
# Epoch 3700: Loss = 0.293 F1 score = 0.674 Val loss = 0.706
# Epoch 3800: Loss = 0.283 F1 score = 0.672 Val loss = 0.707
# Epoch 3900: Loss = 0.273 F1 score = 0.678 Val loss = 0.706
# Epoch 4000: Loss = 0.264 F1 score = 0.68 Val loss = 0.705
# Epoch 4100: Loss = 0.255 F1 score = 0.686 Val loss = 0.705
# Epoch 4200: Loss = 0.246 F1 score = 0.688 Val loss = 0.704
# Epoch 4300: Loss = 0.238 F1 score = 0.689 Val loss = 0.703
# Epoch 4400: Loss = 0.23 F1 score = 0.693 Val loss = 0.704
# Epoch 4500: Loss = 0.223 F1 score = 0.696 Val loss = 0.706
# Epoch 4600: Loss = 0.216 F1 score = 0.696 Val loss = 0.709
# Epoch 4700: Loss = 0.21 F1 score = 0.697 Val loss = 0.707
# Epoch 4800: Loss = 0.204 F1 score = 0.697 Val loss = 0.711
# Epoch 4900: Loss = 0.199 F1 score = 0.705 Val loss = 0.713
# Epoch 5000: Loss = 0.194 F1 score = 0.708 Val loss = 0.717
# Epoch 5100: Loss = 0.189 F1 score = 0.714 Val loss = 0.719
# Epoch 5200: Loss = 0.184 F1 score = 0.713 Val loss = 0.721
# Epoch 5300: Loss = 0.18 F1 score = 0.712 Val loss = 0.727
# Epoch 5400: Loss = 0.176 F1 score = 0.714 Val loss = 0.732
# Epoch 5500: Loss = 0.172 F1 score = 0.714 Val loss = 0.735
# Epoch 5600: Loss = 0.169 F1 score = 0.716 Val loss = 0.737
# Epoch 5700: Loss = 0.166 F1 score = 0.716 Val loss = 0.741
# Epoch 5800: Loss = 0.162 F1 score = 0.717 Val loss = 0.75
# Epoch 5900: Loss = 0.159 F1 score = 0.722 Val loss = 0.75
# Epoch 6000: Loss = 0.157 F1 score = 0.719 Val loss = 0.759
# Epoch 6100: Loss = 0.154 F1 score = 0.719 Val loss = 0.762
# Epoch 6200: Loss = 0.151 F1 score = 0.72 Val loss = 0.764
# Epoch 6300: Loss = 0.149 F1 score = 0.721 Val loss = 0.772
# Epoch 6400: Loss = 0.147 F1 score = 0.721 Val loss = 0.775
# Epoch 6500: Loss = 0.145 F1 score = 0.721 Val loss = 0.782
# Epoch 6600: Loss = 0.142 F1 score = 0.722 Val loss = 0.782
# Epoch 6700: Loss = 0.14 F1 score = 0.721 Val loss = 0.789
# Epoch 6800: Loss = 0.139 F1 score = 0.72 Val loss = 0.798
# Epoch 6900: Loss = 0.137 F1 score = 0.72 Val loss = 0.8
# Epoch 7000: Loss = 0.135 F1 score = 0.719 Val loss = 0.806
# Epoch 7100: Loss = 0.133 F1 score = 0.719 Val loss = 0.811
# Epoch 7200: Loss = 0.131 F1 score = 0.721 Val loss = 0.816
# Epoch 7300: Loss = 0.13 F1 score = 0.72 Val loss = 0.819
# Epoch 7400: Loss = 0.128 F1 score = 0.72 Val loss = 0.828
# Epoch 7500: Loss = 0.127 F1 score = 0.719 Val loss = 0.83
# Epoch 7600: Loss = 0.125 F1 score = 0.72 Val loss = 0.835
# Epoch 7700: Loss = 0.124 F1 score = 0.721 Val loss = 0.842
# Epoch 7800: Loss = 0.122 F1 score = 0.722 Val loss = 0.847
# Epoch 7900: Loss = 0.121 F1 score = 0.722 Val loss = 0.851
# Epoch 8000: Loss = 0.12 F1 score = 0.721 Val loss = 0.856
# Epoch 8100: Loss = 0.118 F1 score = 0.722 Val loss = 0.862
# Epoch 8200: Loss = 0.117 F1 score = 0.723 Val loss = 0.868
# Epoch 8300: Loss = 0.116 F1 score = 0.723 Val loss = 0.872
# Epoch 8400: Loss = 0.115 F1 score = 0.725 Val loss = 0.876
# Epoch 8500: Loss = 0.113 F1 score = 0.724 Val loss = 0.881
# Epoch 8600: Loss = 0.112 F1 score = 0.724 Val loss = 0.884
# Epoch 8700: Loss = 0.111 F1 score = 0.723 Val loss = 0.887
# Epoch 8800: Loss = 0.11 F1 score = 0.724 Val loss = 0.891
# Epoch 8900: Loss = 0.108 F1 score = 0.724 Val loss = 0.901
# Epoch 9000: Loss = 0.107 F1 score = 0.723 Val loss = 0.901
# Epoch 9100: Loss = 0.106 F1 score = 0.725 Val loss = 0.909
# Epoch 9200: Loss = 0.105 F1 score = 0.725 Val loss = 0.911
# Epoch 9300: Loss = 0.103 F1 score = 0.725 Val loss = 0.917
# Epoch 9400: Loss = 0.102 F1 score = 0.725 Val loss = 0.923
# Epoch 9500: Loss = 0.101 F1 score = 0.723 Val loss = 0.925
# Epoch 9600: Loss = 0.1 F1 score = 0.723 Val loss = 0.928
# Epoch 9700: Loss = 0.098 F1 score = 0.725 Val loss = 0.934
# Epoch 9800: Loss = 0.097 F1 score = 0.723 Val loss = 0.94
# Epoch 9900: Loss = 0.095 F1 score = 0.721 Val loss = 0.944
# Epoch 10000: Loss = 0.094 F1 score = 0.721 Val loss = 0.949

# %%
plt.figure(figsize=(12,4))
plt.subplot(1, 3, 1)
history5_reg.plot_loss(loss_type='train', return_plot=True, settings='y')
plt.subplot(1, 3, 2)
history5_reg.plot_loss(loss_type='test', return_plot=True, settings='y')
plt.title('Test f1 score')
plt.ylabel('F1 score')
plt.subplot(1, 3, 3)
history5_reg.plot_loss(loss_type='val', return_plot=True, settings='y')
plt.tight_layout()
plt.show()
print(f"final f1 score: {round(nn5_reg.f1_score(X_test5, y_test), 3)}")
# Out:
# final f1 score: 0.721

# %%
# Otrzymaliśmy najlepszy f1 score. Można zauważyć, że gdybyśmy zastosowali teraz early stopping, to trening zatrzymałby się około 4500 tysięcznej epoki, a w tym miejscu f1 score nie jest optymalny, 
# więc early stopping nie zawsze daje najlepsze możliwe wyniki. Na koniec porównanie 3 metod:

# %%
plt.figure(figsize=(16,4))
plt.subplot(1,4,1)
nn5.plot_classes(X_test3)
plt.title('default')
plt.subplot(1,4,2)
nn5_val.plot_classes(X_test3)
plt.title('with early stopping')
plt.subplot(1,4,3)
nn5_reg.plot_classes(X_test3)
plt.title('with regularization')
plt.subplot(1,4,4)
plot_classes(X_test5, decode_array(y_test))
plt.title('test')
plt.tight_layout()
plt.show()

# %%
# Na oko wszystkie metody poradziły sobie podobnie. Jednakże z regularyzacją otrzymaliśmy najlepszy f1 score, z kolei z early stoppingiem trening trwał 3 razy szybciej

# %% [markdown]
# ### multimodal-large

# %%
multi_test = pd.read_csv("../dane/regression/multimodal-sparse-test.csv")
multi_train = pd.read_csv("../dane/regression/multimodal-sparse-training.csv")

# %%
X_train = multi_train['x']
y_train = multi_train['y']
X_test, X_val, y_test, y_val = train_test_split(multi_test['x'], multi_test['y'], random_state=42, test_size=0.5)
y_norm_modal, parameters_modal = standardize_data(y_train)

# %% [markdown]
# - Default model

# %%
nnm = NeuralNetwork([1,10,10,1], model_type='regression')
historym = nnm.train(X_train, y_norm_modal, learning_rate=0.1, info_interval=400, epochs=40000, batch_size=25,
                    optimize='moment', return_history=True, resize=True, denormalize=parameters_modal, X_test=X_test, y_test=y_test, X_val=X_val, y_val=y_val)
# Out:
# Epoch 400: Loss = 1680.464 test loss = 1953.499 Val loss = 2016.267
# Epoch 800: Loss = 660.114 test loss = 1151.832 Val loss = 945.207
# Epoch 1200: Loss = 256.794 test loss = 685.286 Val loss = 604.235
# Epoch 1600: Loss = 239.359 test loss = 589.02 Val loss = 489.054
# Epoch 2000: Loss = 227.744 test loss = 582.725 Val loss = 444.61
# Epoch 2400: Loss = 226.115 test loss = 568.502 Val loss = 424.664
# Epoch 2800: Loss = 244.792 test loss = 635.006 Val loss = 462.332
# Epoch 3200: Loss = 221.052 test loss = 561.248 Val loss = 425.066
# Epoch 3600: Loss = 220.759 test loss = 546.567 Val loss = 421.344
# Epoch 4000: Loss = 232.162 test loss = 607.94 Val loss = 416.951
# Epoch 4400: Loss = 245.489 test loss = 615.319 Val loss = 442.444
# Epoch 4800: Loss = 229.472 test loss = 591.48 Val loss = 411.547
# Epoch 5200: Loss = 221.261 test loss = 543.156 Val loss = 378.059
# Epoch 5600: Loss = 226.497 test loss = 583.578 Val loss = 399.617
# Epoch 6000: Loss = 219.69 test loss = 565.961 Val loss = 392.944
# Epoch 6400: Loss = 214.84 test loss = 544.364 Val loss = 387.975
# Epoch 6800: Loss = 217.727 test loss = 558.33 Val loss = 380.413
# Epoch 7200: Loss = 213.608 test loss = 535.146 Val loss = 373.159
# Epoch 7600: Loss = 214.165 test loss = 544.345 Val loss = 363.634
# Epoch 8000: Loss = 214.952 test loss = 538.145 Val loss = 378.917
# Epoch 8400: Loss = 214.274 test loss = 549.152 Val loss = 379.062
# Epoch 8800: Loss = 212.141 test loss = 532.176 Val loss = 365.954
# Epoch 9200: Loss = 213.662 test loss = 541.382 Val loss = 370.791
# Epoch 9600: Loss = 226.666 test loss = 572.348 Val loss = 387.078
# Epoch 10000: Loss = 211.399 test loss = 534.235 Val loss = 363.381
# Epoch 10400: Loss = 215.396 test loss = 520.482 Val loss = 359.472
# Epoch 10800: Loss = 210.706 test loss = 527.163 Val loss = 361.224
# Epoch 11200: Loss = 212.235 test loss = 534.467 Val loss = 355.542
# Epoch 11600: Loss = 211.26 test loss = 517.528 Val loss = 356.183
# Epoch 12000: Loss = 210.056 test loss = 523.764 Val loss = 349.669
# Epoch 12400: Loss = 210.686 test loss = 505.612 Val loss = 357.472
# Epoch 12800: Loss = 209.93 test loss = 514.219 Val loss = 353.956
# Epoch 13200: Loss = 209.518 test loss = 522.168 Val loss = 350.678
# Epoch 13600: Loss = 210.286 test loss = 503.145 Val loss = 349.798
# Epoch 14000: Loss = 212.114 test loss = 507.854 Val loss = 345.806
# Epoch 14400: Loss = 218.714 test loss = 539.027 Val loss = 351.768
# Epoch 14800: Loss = 210.116 test loss = 517.977 Val loss = 358.759
# Epoch 15200: Loss = 213.562 test loss = 495.916 Val loss = 348.242
# Epoch 15600: Loss = 209.185 test loss = 499.625 Val loss = 346.735
# Epoch 16000: Loss = 210.899 test loss = 510.289 Val loss = 346.382
# Epoch 16400: Loss = 208.263 test loss = 515.047 Val loss = 339.335
# Epoch 16800: Loss = 209.043 test loss = 499.175 Val loss = 342.725
# Epoch 17200: Loss = 206.754 test loss = 512.3 Val loss = 348.894
# Epoch 17600: Loss = 206.409 test loss = 504.026 Val loss = 338.521
# Epoch 18000: Loss = 217.431 test loss = 542.54 Val loss = 360.055
# Epoch 18400: Loss = 206.348 test loss = 500.202 Val loss = 341.858
# Epoch 18800: Loss = 205.453 test loss = 505.668 Val loss = 339.281
# Epoch 19200: Loss = 207.78 test loss = 494.709 Val loss = 344.38
# Epoch 19600: Loss = 205.692 test loss = 500.097 Val loss = 333.814
# Epoch 20000: Loss = 216.966 test loss = 538.454 Val loss = 353.598
# Epoch 20400: Loss = 205.207 test loss = 500.007 Val loss = 332.534
# Epoch 20800: Loss = 207.649 test loss = 512.791 Val loss = 340.995
# Epoch 21200: Loss = 206.203 test loss = 492.433 Val loss = 335.472
# Epoch 21600: Loss = 203.892 test loss = 500.039 Val loss = 339.295
# Epoch 22000: Loss = 206.365 test loss = 489.976 Val loss = 339.315
# Epoch 22400: Loss = 209.44 test loss = 493.525 Val loss = 344.343
# Epoch 22800: Loss = 204.518 test loss = 486.15 Val loss = 342.587
# Epoch 23200: Loss = 203.061 test loss = 500.01 Val loss = 338.045
# Epoch 23600: Loss = 204.142 test loss = 480.973 Val loss = 335.005
# Epoch 24000: Loss = 202.739 test loss = 493.724 Val loss = 330.466
# Epoch 24400: Loss = 202.285 test loss = 491.168 Val loss = 331.183
# Epoch 24800: Loss = 203.347 test loss = 505.54 Val loss = 333.262
# Epoch 25200: Loss = 201.17 test loss = 485.396 Val loss = 339.015
# Epoch 25600: Loss = 203.775 test loss = 491.85 Val loss = 332.933
# Epoch 26000: Loss = 208.341 test loss = 472.941 Val loss = 332.801
# Epoch 26400: Loss = 212.545 test loss = 466.7 Val loss = 338.686
# Epoch 26800: Loss = 199.291 test loss = 476.571 Val loss = 333.851
# Epoch 27200: Loss = 200.249 test loss = 462.674 Val loss = 326.76
# Epoch 27600: Loss = 198.228 test loss = 455.706 Val loss = 319.509
# Epoch 28000: Loss = 204.28 test loss = 443.767 Val loss = 322.401
# Epoch 28400: Loss = 197.72 test loss = 470.561 Val loss = 326.846
# Epoch 28800: Loss = 188.116 test loss = 437.23 Val loss = 315.276
# Epoch 29200: Loss = 184.134 test loss = 412.911 Val loss = 308.484
# Epoch 29600: Loss = 187.251 test loss = 428.523 Val loss = 316.084
# Epoch 30000: Loss = 168.567 test loss = 386.311 Val loss = 292.671
# Epoch 30400: Loss = 152.79 test loss = 342.341 Val loss = 277.064
# Epoch 30800: Loss = 128.833 test loss = 305.324 Val loss = 263.005
# Epoch 31200: Loss = 90.527 test loss = 221.791 Val loss = 220.565
# Epoch 31600: Loss = 55.935 test loss = 180.82 Val loss = 187.912
# Epoch 32000: Loss = 37.647 test loss = 150.309 Val loss = 172.191
# Epoch 32400: Loss = 28.817 test loss = 135.303 Val loss = 159.023
# Epoch 32800: Loss = 23.617 test loss = 125.792 Val loss = 147.843
# Epoch 33200: Loss = 20.802 test loss = 119.624 Val loss = 145.969
# Epoch 33600: Loss = 19.374 test loss = 116.936 Val loss = 140.327
# Epoch 34000: Loss = 17.385 test loss = 113.096 Val loss = 138.852
# Epoch 34400: Loss = 16.361 test loss = 110.32 Val loss = 132.521
# Epoch 34800: Loss = 15.38 test loss = 106.803 Val loss = 132.246
# Epoch 35200: Loss = 14.455 test loss = 104.447 Val loss = 129.015
# Epoch 35600: Loss = 13.942 test loss = 101.567 Val loss = 129.851
# Epoch 36000: Loss = 13.614 test loss = 99.032 Val loss = 124.761
# Epoch 36400: Loss = 13.156 test loss = 96.802 Val loss = 124.595
# Epoch 36800: Loss = 12.797 test loss = 93.386 Val loss = 120.72
# Epoch 37200: Loss = 12.57 test loss = 91.256 Val loss = 118.44
# Epoch 37600: Loss = 12.374 test loss = 89.479 Val loss = 117.009
# Epoch 38000: Loss = 12.254 test loss = 86.372 Val loss = 115.138
# Epoch 38400: Loss = 12.24 test loss = 84.715 Val loss = 110.742
# Epoch 38800: Loss = 12.192 test loss = 82.962 Val loss = 107.839
# Epoch 39200: Loss = 11.966 test loss = 81.414 Val loss = 106.157
# Epoch 39600: Loss = 11.763 test loss = 78.827 Val loss = 106.822
# Epoch 40000: Loss = 11.831 test loss = 77.067 Val loss = 101.537

# %%
plt.figure(figsize=(12,4))
plt.subplot(1, 3, 1)
historym.plot_loss(loss_type='train', return_plot=True)
plt.subplot(1, 3, 2)
historym.plot_loss(loss_type='test', return_plot=True)
plt.subplot(1, 3, 3)
historym.plot_loss(loss_type='val', return_plot=True)
plt.tight_layout()
plt.show()
print(f"final mse: {round(nnm.mse(X_test, y_test, resize=True, denormalize=parameters_modal), 3)}")
# Out:
# final mse: 77.067

# %% [markdown]
# - Validation early stopping

# %%
nnm_val = NeuralNetwork([1,10,10,1], model_type='regression')
historym_val = nnm_val.train(X_train, y_norm_modal, learning_rate=0.1, info_interval=400, epochs=40000, batch_size=25, val_stopping_k=5, window_size=100,
                    optimize='moment', return_history=True, resize=True, denormalize=parameters_modal, X_test=X_test, y_test=y_test, X_val=X_val, y_val=y_val)
# Out:
# Epoch 400: Loss = 1551.562 test loss = 1806.891 Val loss = 1915.37
# Epoch 800: Loss = 607.951 test loss = 1085.233 Val loss = 927.223
# Epoch 1200: Loss = 250.739 test loss = 677.986 Val loss = 589.785
# Epoch 1600: Loss = 222.487 test loss = 574.346 Val loss = 492.683
# Epoch 2000: Loss = 219.7 test loss = 551.253 Val loss = 454.989
# Epoch 2400: Loss = 216.634 test loss = 512.417 Val loss = 436.753
# Epoch 2800: Loss = 227.945 test loss = 502.491 Val loss = 420.097
# Epoch 3200: Loss = 217.632 test loss = 531.997 Val loss = 423.703
# Epoch 3600: Loss = 213.87 test loss = 512.356 Val loss = 386.197
# Epoch 4000: Loss = 214.815 test loss = 529.347 Val loss = 391.039
# Epoch 4400: Loss = 211.513 test loss = 516.504 Val loss = 385.545
# Epoch 4800: Loss = 211.884 test loss = 515.318 Val loss = 397.744
# Epoch 5200: Loss = 210.782 test loss = 510.472 Val loss = 385.394
# Epoch 5600: Loss = 211.694 test loss = 515.783 Val loss = 369.493
# Epoch 6000: Loss = 210.853 test loss = 490.833 Val loss = 368.54
# Epoch 6400: Loss = 220.125 test loss = 542.223 Val loss = 380.474
# Epoch 6800: Loss = 208.84 test loss = 491.28 Val loss = 363.064
# Epoch 7200: Loss = 227.993 test loss = 559.376 Val loss = 395.836
# Epoch 7600: Loss = 210.042 test loss = 512.339 Val loss = 361.736
# Epoch 8000: Loss = 212.142 test loss = 471.715 Val loss = 361.66
# Epoch 8400: Loss = 208.541 test loss = 482.03 Val loss = 367.445
# Epoch 8800: Loss = 213.793 test loss = 523.635 Val loss = 364.417
# Epoch 9200: Loss = 208.924 test loss = 500.084 Val loss = 363.209
# Epoch 9600: Loss = 212.059 test loss = 514.454 Val loss = 362.371
# Epoch 10000: Loss = 206.891 test loss = 493.96 Val loss = 345.92
# Epoch 10400: Loss = 216.362 test loss = 455.86 Val loss = 348.274
# Epoch 10800: Loss = 209.088 test loss = 496.804 Val loss = 358.079
# Epoch 11200: Loss = 204.263 test loss = 477.616 Val loss = 342.186
# Epoch 11600: Loss = 208.43 test loss = 492.729 Val loss = 360.978
# Epoch 12000: Loss = 204.681 test loss = 480.664 Val loss = 329.485
# Epoch 12400: Loss = 206.6 test loss = 452.859 Val loss = 338.218
# Epoch 12800: Loss = 202.096 test loss = 461.438 Val loss = 339.085
# Epoch 13200: Loss = 201.819 test loss = 444.307 Val loss = 333.148
# Epoch 13600: Loss = 201.79 test loss = 458.683 Val loss = 332.621
# Epoch 14000: Loss = 206.126 test loss = 427.203 Val loss = 332.044
# Epoch 14400: Loss = 200.943 test loss = 463.122 Val loss = 336.891
# Epoch 14800: Loss = 199.68 test loss = 437.451 Val loss = 325.128
# Epoch 15200: Loss = 201.242 test loss = 429.438 Val loss = 312.261
# Epoch 15600: Loss = 202.002 test loss = 459.47 Val loss = 335.833
# Epoch 16000: Loss = 195.699 test loss = 432.561 Val loss = 321.773
# Epoch 16400: Loss = 194.276 test loss = 429.953 Val loss = 319.726
# Epoch 16800: Loss = 193.797 test loss = 433.316 Val loss = 310.792
# Epoch 17200: Loss = 192.301 test loss = 417.176 Val loss = 306.673
# Epoch 17600: Loss = 189.945 test loss = 394.698 Val loss = 307.627
# Epoch 18000: Loss = 190.229 test loss = 403.449 Val loss = 293.81
# Epoch 18400: Loss = 185.151 test loss = 381.333 Val loss = 298.263
# Epoch 18800: Loss = 183.409 test loss = 395.979 Val loss = 306.667
# Epoch 19200: Loss = 179.235 test loss = 381.185 Val loss = 298.996
# Epoch 19600: Loss = 176.562 test loss = 377.475 Val loss = 280.864
# Epoch 20000: Loss = 169.509 test loss = 349.549 Val loss = 285.781
# Epoch 20400: Loss = 162.248 test loss = 329.143 Val loss = 274.157
# Epoch 20800: Loss = 158.027 test loss = 329.261 Val loss = 261.557
# Epoch 21200: Loss = 150.672 test loss = 317.262 Val loss = 272.866
# Epoch 21600: Loss = 144.878 test loss = 267.773 Val loss = 246.19
# Epoch 22000: Loss = 132.733 test loss = 259.99 Val loss = 231.62
# Epoch 22400: Loss = 124.282 test loss = 255.5 Val loss = 229.442
# Epoch 22800: Loss = 111.312 test loss = 245.041 Val loss = 240.311
# Epoch 23200: Loss = 102.742 test loss = 238.339 Val loss = 233.183
# Epoch 23600: Loss = 99.698 test loss = 241.179 Val loss = 256.532
# Epoch 24000: Loss = 90.835 test loss = 232.92 Val loss = 243.824
# Epoch 24400: Loss = 81.238 test loss = 229.736 Val loss = 237.143
# Epoch 24800: Loss = 78.35 test loss = 236.82 Val loss = 238.894
# validation stopping: 241.50350448021064
# [241.30183774707314, 242.92619864622506, 244.23051563241256, 245.32967265732302, 248.30898237207882]

# %%
plt.figure(figsize=(12,4))
plt.subplot(1, 3, 1)
historym_val.plot_loss(loss_type='train', return_plot=True, settings='r')
plt.subplot(1, 3, 2)
historym_val.plot_loss(loss_type='test', return_plot=True, settings='r')
plt.subplot(1, 3, 3)
historym_val.plot_loss(loss_type='val', return_plot=True, settings='r')
plt.tight_layout()
plt.show()
print(f"final mse: {round(nnm_val.mse(X_test, y_test, resize=True, denormalize=parameters_modal), 3)}")
# Out:
# final mse: 231.83

# %%
# Widzimy, że early stopping nie zawsze się sprawdza. Pomimo tego, że długo nic się nie zmienia, to około 30000 epoki mse drastycznie spada. Early stopping jednak zatrzymuje trening nieco wcześniej,
# przez to nie dochodzi do optymalnej wartości.

# %% [markdown]
# - Regularization

# %%
nnm_reg = NeuralNetwork([1,10,10,1], model_type='regression')
historym_reg = nnm_reg.train(X_train, y_norm_modal, learning_rate=0.1, info_interval=400, epochs=40000, batch_size=25, l2_lambda=0.001,
                    optimize='moment', return_history=True, resize=True, denormalize=parameters_modal, X_test=X_test, y_test=y_test, X_val=X_val, y_val=y_val)
# Out:
# Epoch 400: Loss = 1731.949 test loss = 1909.187 Val loss = 1980.949
# Epoch 800: Loss = 692.914 test loss = 1068.622 Val loss = 931.572
# Epoch 1200: Loss = 373.638 test loss = 756.451 Val loss = 583.909
# Epoch 1600: Loss = 248.011 test loss = 565.492 Val loss = 505.877
# Epoch 2000: Loss = 244.944 test loss = 542.127 Val loss = 507.729
# Epoch 2400: Loss = 229.731 test loss = 558.399 Val loss = 514.382
# Epoch 2800: Loss = 250.81 test loss = 543.742 Val loss = 470.967
# Epoch 3200: Loss = 227.171 test loss = 562.071 Val loss = 452.834
# Epoch 3600: Loss = 223.241 test loss = 535.057 Val loss = 449.478
# Epoch 4000: Loss = 237.624 test loss = 581.039 Val loss = 485.872
# Epoch 4400: Loss = 234.777 test loss = 533.503 Val loss = 436.144
# Epoch 4800: Loss = 239.143 test loss = 540.828 Val loss = 415.112
# Epoch 5200: Loss = 224.649 test loss = 521.645 Val loss = 420.027
# Epoch 5600: Loss = 260.713 test loss = 607.391 Val loss = 500.025
# Epoch 6000: Loss = 267.155 test loss = 544.964 Val loss = 429.977
# Epoch 6400: Loss = 218.301 test loss = 535.217 Val loss = 417.41
# Epoch 6800: Loss = 218.366 test loss = 524.591 Val loss = 419.397
# Epoch 7200: Loss = 243.782 test loss = 573.104 Val loss = 466.807
# Epoch 7600: Loss = 244.465 test loss = 532.713 Val loss = 416.657
# Epoch 8000: Loss = 229.663 test loss = 557.496 Val loss = 431.694
# Epoch 8400: Loss = 218.811 test loss = 522.943 Val loss = 423.326
# Epoch 8800: Loss = 229.435 test loss = 531.935 Val loss = 407.574
# Epoch 9200: Loss = 225.178 test loss = 545.466 Val loss = 426.903
# Epoch 9600: Loss = 216.734 test loss = 524.832 Val loss = 412.939
# Epoch 10000: Loss = 223.977 test loss = 526.077 Val loss = 434.729
# Epoch 10400: Loss = 216.742 test loss = 525.922 Val loss = 398.856
# Epoch 10800: Loss = 216.09 test loss = 525.174 Val loss = 402.753
# Epoch 11200: Loss = 218.763 test loss = 519.057 Val loss = 389.431
# Epoch 11600: Loss = 235.299 test loss = 527.432 Val loss = 390.18
# Epoch 12000: Loss = 218.992 test loss = 528.49 Val loss = 387.958
# Epoch 12400: Loss = 223.278 test loss = 507.153 Val loss = 397.529
# Epoch 12800: Loss = 217.625 test loss = 526.396 Val loss = 405.976
# Epoch 13200: Loss = 220.589 test loss = 513.107 Val loss = 381.161
# Epoch 13600: Loss = 218.294 test loss = 531.466 Val loss = 388.771
# Epoch 14000: Loss = 224.276 test loss = 526.124 Val loss = 382.525
# Epoch 14400: Loss = 218.009 test loss = 510.138 Val loss = 386.384
# Epoch 14800: Loss = 215.731 test loss = 507.2 Val loss = 390.672
# Epoch 15200: Loss = 214.583 test loss = 527.024 Val loss = 387.1
# Epoch 15600: Loss = 215.336 test loss = 526.119 Val loss = 392.867
# Epoch 16000: Loss = 225.24 test loss = 532.471 Val loss = 410.589
# Epoch 16400: Loss = 224.697 test loss = 502.427 Val loss = 384.174
# Epoch 16800: Loss = 214.359 test loss = 507.641 Val loss = 390.659
# Epoch 17200: Loss = 212.935 test loss = 511.278 Val loss = 381.39
# Epoch 17600: Loss = 220.364 test loss = 510.425 Val loss = 376.066
# Epoch 18000: Loss = 216.812 test loss = 508.306 Val loss = 374.248
# Epoch 18400: Loss = 213.594 test loss = 501.993 Val loss = 383.908
# Epoch 18800: Loss = 217.786 test loss = 507.366 Val loss = 372.622
# Epoch 19200: Loss = 231.238 test loss = 515.026 Val loss = 377.706
# Epoch 19600: Loss = 212.651 test loss = 510.557 Val loss = 371.537
# Epoch 20000: Loss = 214.04 test loss = 529.303 Val loss = 375.587
# Epoch 20400: Loss = 218.141 test loss = 509.215 Val loss = 374.09
# Epoch 20800: Loss = 212.197 test loss = 506.843 Val loss = 378.55
# Epoch 21200: Loss = 211.466 test loss = 504.994 Val loss = 370.923
# Epoch 21600: Loss = 213.678 test loss = 493.151 Val loss = 377.134
# Epoch 22000: Loss = 211.73 test loss = 509.929 Val loss = 364.269
# Epoch 22400: Loss = 210.59 test loss = 502.041 Val loss = 365.488
# Epoch 22800: Loss = 212.845 test loss = 514.662 Val loss = 359.038
# Epoch 23200: Loss = 224.235 test loss = 513.57 Val loss = 409.269
# Epoch 23600: Loss = 216.383 test loss = 503.555 Val loss = 360.708
# Epoch 24000: Loss = 211.502 test loss = 496.242 Val loss = 372.288
# Epoch 24400: Loss = 210.386 test loss = 510.915 Val loss = 360.349
# Epoch 24800: Loss = 210.482 test loss = 490.923 Val loss = 358.622
# Epoch 25200: Loss = 211.343 test loss = 490.425 Val loss = 361.611
# Epoch 25600: Loss = 209.125 test loss = 501.949 Val loss = 356.298
# Epoch 26000: Loss = 217.119 test loss = 497.35 Val loss = 358.959
# Epoch 26400: Loss = 208.914 test loss = 486.904 Val loss = 355.227
# Epoch 26800: Loss = 209.428 test loss = 490.316 Val loss = 358.337
# Epoch 27200: Loss = 214.23 test loss = 495.007 Val loss = 354.449
# Epoch 27600: Loss = 208.56 test loss = 495.151 Val loss = 358.827
# Epoch 28000: Loss = 207.993 test loss = 498.558 Val loss = 350.813
# Epoch 28400: Loss = 208.118 test loss = 493.105 Val loss = 348.182
# Epoch 28800: Loss = 209.31 test loss = 482.498 Val loss = 355.317
# Epoch 29200: Loss = 210.098 test loss = 490.063 Val loss = 345.11
# Epoch 29600: Loss = 208.898 test loss = 489.723 Val loss = 348.529
# Epoch 30000: Loss = 206.965 test loss = 489.342 Val loss = 348.077
# Epoch 30400: Loss = 208.333 test loss = 487.161 Val loss = 350.3
# Epoch 30800: Loss = 213.967 test loss = 490.78 Val loss = 347.366
# Epoch 31200: Loss = 206.843 test loss = 481.762 Val loss = 342.39
# Epoch 31600: Loss = 206.884 test loss = 480.254 Val loss = 349.555
# Epoch 32000: Loss = 208.616 test loss = 496.691 Val loss = 344.452
# Epoch 32400: Loss = 226.989 test loss = 518.38 Val loss = 378.763
# Epoch 32800: Loss = 206.678 test loss = 472.817 Val loss = 346.809
# Epoch 33200: Loss = 207.243 test loss = 483.525 Val loss = 345.429
# Epoch 33600: Loss = 209.124 test loss = 483.409 Val loss = 339.696
# Epoch 34000: Loss = 205.953 test loss = 477.991 Val loss = 339.752
# Epoch 34400: Loss = 206.482 test loss = 489.436 Val loss = 348.333
# Epoch 34800: Loss = 207.11 test loss = 480.87 Val loss = 337.169
# Epoch 35200: Loss = 205.042 test loss = 477.525 Val loss = 345.222
# Epoch 35600: Loss = 204.973 test loss = 480.553 Val loss = 334.819
# Epoch 36000: Loss = 205.206 test loss = 475.729 Val loss = 337.661
# Epoch 36400: Loss = 205.366 test loss = 479.204 Val loss = 346.082
# Epoch 36800: Loss = 206.734 test loss = 471.782 Val loss = 343.069
# Epoch 37200: Loss = 204.643 test loss = 457.05 Val loss = 334.645
# Epoch 37600: Loss = 203.639 test loss = 461.796 Val loss = 337.008
# Epoch 38000: Loss = 202.852 test loss = 467.918 Val loss = 335.199
# Epoch 38400: Loss = 205.84 test loss = 471.462 Val loss = 344.841
# Epoch 38800: Loss = 202.115 test loss = 453.916 Val loss = 337.436
# Epoch 39200: Loss = 200.599 test loss = 455.366 Val loss = 332.055
# Epoch 39600: Loss = 200.855 test loss = 459.463 Val loss = 328.738
# Epoch 40000: Loss = 198.816 test loss = 447.22 Val loss = 333.605

# %%
plt.figure(figsize=(12,4))
plt.subplot(1, 3, 1)
historym_reg.plot_loss(loss_type='train', return_plot=True, settings='y')
plt.subplot(1, 3, 2)
historym_reg.plot_loss(loss_type='test', return_plot=True, settings='y')
plt.subplot(1, 3, 3)
historym_reg.plot_loss(loss_type='val', return_plot=True, settings='y')
plt.tight_layout()
plt.show()
print(f"final mse: {round(nnm_reg.mse(X_test, y_test, resize=True, denormalize=parameters_modal), 3)}")
# Out:
# final mse: 447.22

# %%
plt.figure(figsize=(14,4))

plt.subplot(1,3,1)
preds_modal = nnm.predict(X_test.to_numpy().reshape(-1,1))
preds_modal_denorm = destandardize_data(preds_modal, parameters_modal)
plt.scatter(X_test, y_test)
plt.scatter(X_test, preds_modal_denorm, s=10)
plt.legend(['test', 'predictions'])
plt.title('default')

plt.subplot(1,3,2)
preds_modal = nnm_val.predict(X_test.to_numpy().reshape(-1,1))
preds_modal_denorm = destandardize_data(preds_modal, parameters_modal)
plt.scatter(X_test, y_test)
plt.scatter(X_test, preds_modal_denorm, s=10)
plt.title('early stopping')

plt.subplot(1,3,3)
preds_modal = nnm_reg.predict(X_test.to_numpy().reshape(-1,1))
preds_modal_denorm = destandardize_data(preds_modal, parameters_modal)
plt.scatter(X_test, y_test)
plt.scatter(X_test, preds_modal_denorm, s=10)
plt.title('regularization')

plt.show()

# %%
# Regularyzacja zupełnie nie działa, early stopping też nie pomógł

# %%
plt.figure(figsize=(10,4))
plt.subplot(1, 2, 1)
historym.plot_weights(2, return_plot=True)
plt.title("Weights values at layer 0, no regularization")
plt.subplot(1, 2, 2)
historym_reg.plot_weights(2, return_plot=True)
plt.title("Weights values at layer 0, with regularization")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### xor3

# %%
xor_test = pd.read_csv("../dane/classification/xor3-balance-test.csv", index_col=0).reset_index()
xor_train = pd.read_csv("../dane/classification/xor3-balance-training.csv", index_col=0).reset_index()

# %%
X_train = xor_train[['x', 'y']].to_numpy()
y_train = one_hot_encode(xor_train['c'])
X_val, X_test, y_val, y_test = train_test_split(xor_test[['x', 'y']].to_numpy(), one_hot_encode(xor_test['c']),
                                                test_size=0.5, random_state=42)
X_train_xor, _ = standardize_data(X_train)
X_test_xor, _ = standardize_data(X_test)
X_val_xor, _ = standardize_data(X_val)

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plot_classes(X_train_xor, decode_array(y_train))
plt.title('train')
plt.subplot(1,2,2)
plot_classes(X_test_xor, decode_array(y_test))
plt.title('test')
plt.show()

# %% [markdown]
# Dla tego zestawu sprawdzimy różne wartości regularyzacji

# %%
lambdas = [None, 0.00001, 0.0001, 0.001, 0.01, 0.1]
colors = ['b', 'r', 'y', 'g', 'k', 'm']
legend_handles = [Patch(color=color, label=label) for label, color in zip(lambdas, colors)]

plt.figure(figsize=(14,4))
for l2_lambda, color in tqdm(zip(lambdas, colors)):
    nn_xor = NeuralNetwork([2,10,10,2], model_type='classification')
    history_xor = nn_xor.train(X_train_xor, y_train, learning_rate=0.05, info_interval=100, epochs=6000, batch_size=50, l2_lambda=l2_lambda,
        X_test=X_test_xor, y_test=y_test, optimize='moment', return_history=True, X_val=X_val_xor, y_val=y_val, mute_print=True)
    
    plt.subplot(1, 3, 1)
    history_xor.plot_loss(loss_type='train', return_plot=True, settings=color)
    plt.subplot(1, 3, 2)
    history_xor.plot_loss(loss_type='test', return_plot=True, settings=color)
    plt.title('Test f1 score')
    plt.ylabel('F1 Score')
    plt.subplot(1, 3, 3)
    history_xor.plot_loss(loss_type='val', return_plot=True, settings=color)
    plt.tight_layout()
plt.legend(handles=legend_handles)
# Out:
# 6it [03:53, 38.99s/it]

# %%
# Widzimy, że w przypadku gdy nasze dane potrzebują uogólnienia, najlepsze wyniki daje nieduża wartość współczynnika regularyzacji.

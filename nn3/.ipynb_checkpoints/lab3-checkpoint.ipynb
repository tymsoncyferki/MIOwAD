# %% [markdown]
# # NN2
# Tymoteusz Urban

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import time
import copy
from tqdm import tqdm
# Out:
# C:\Users\tymek\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\tymek\AppData\Roaming\Python\Python39\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
class NeuralNetwork:
    
    """
    Implementation of multi layer perceptron

    Attributes
    -----------
    layers : List
    
    """
    
    def __init__(self, layers, weights=None, biases=None, activations=None, initalization='xavier'):
        """
        activations - available functions: 'sigmoid', 'linear'
        initialization - available types: 'xavier', 'he', 'uniform'
        """
        self.layers = layers
        self.num_layers = len(layers)
        
        initialization_functions = {
            'xavier': self.xavier_init,
            'he': self.he_init,
            'uniform': self.uniform_init
        }
        self.init_function = initialization_functions.get(initalization)
        
        if weights is None:
            self.weights = [self.init_function(layers[i-1], layers[i]) for i in range(1, self.num_layers)]
        else:
            self.weights = weights
        
        if biases is None:
            self.biases = [self.init_function(layers[i]) for i in range(1, self.num_layers)]
        else:
            self.biases = biases
        
        if activations is None:
            self.activations = ['sigmoid' for i in range(1, self.num_layers - 1)] + ['linear']
        else:
            self.activations = activations
        
        self.velocities_weights = [self.zeros_init(layers[i-1], layers[i]) for i in range(1, self.num_layers)]
        self.velocities_biases = [self.zeros_init(layers[i]) for i in range(1, self.num_layers)]
        
        activation_functions = {
            'sigmoid': self._sigmoid,
            'linear': self._linear
        }
        self.activation_funcs = list(map(lambda x: activation_functions.get(x), self.activations))
        
        self.mean = None
        self.std = None
    
    def _sigmoid(self, z):
        return 1 / (1 + np.exp(-z))

    def _linear(self, z):
        return z
    
    def xavier_init(self, n_in, n_out=None):
        if n_out is None:
            n_out = n_in
            variance = 1 / n_out
            stddev = np.sqrt(variance)
            return np.random.normal(0, stddev, n_out)
        variance = 2 / (n_in + n_out)
        stddev = np.sqrt(variance)
        return np.random.normal(0, stddev, (n_in, n_out))
        
    def he_init(self, n_in, n_out=None):
        if n_out is None:
            variance = 2 / n_in
            stddev = np.sqrt(variance)
            return np.random.normal(0, stddev, n_in)
        variance = 2 / n_in
        stddev = np.sqrt(variance)
        return np.random.normal(0, stddev, (n_in, n_out))
    
    def zeros_init(self, n_in, n_out=None):
        if n_out is None:
            return np.zeros(n_in)
        return np.zeros((n_in, n_out))
    
    def uniform_init(self, n_in, n_out=None):
        if n_out is None:
            return np.random.uniform(0, 1, n_in)
        return np.random.uniform(0, 1, (n_in, n_out))
    
    def feedforward(self, a, return_activations=False):
        if return_activations:
            activations = [a]
            for w, b, func in zip(self.weights, self.biases, self.activation_funcs):
#                 print('a', type(a))
#                 print('w', type(w))
#                 print('b', type(b))
                z = np.dot(a, w) + b
                a = func(z)
                activations.append(a)
            return activations
        else:
            for w, b, func in zip(self.weights, self.biases, self.activation_funcs):
                z = np.dot(a, w) + b
                a = func(z)
            return a
    
    def predict(self, X):
        return self.feedforward(X)
    
    def mse(self, X, y, resize=False, denormalize=None):
        """
        first predictions are made, then denormalized and then mse is calculated
        
        denormalize - a tuple (mean, std)
        """
        if resize:
            X = X.to_numpy().reshape(-1, 1)
            y = y.to_numpy().reshape(-1, 1)
        predictions = self.predict(X)
        if denormalize:
            predictions = destandardize_data(predictions, denormalize)
        return np.mean((predictions - y) ** 2)
    
    def sigmoid_derivative(self, a):
        """calculates sigm'(z) where a = sigm(z)"""
        return a * (1-a)
    
    def backward(self, X, y):
        """backpropagation, returns partial derevatives"""
        # feedforward
        activations = self.feedforward(X, return_activations=True)
        deltas = [None] * len(self.weights)
        # output error
        deltas[-1] = activations[-1] - y.reshape(-1, 1)
        # calculate neurons' errors using backpropagation 
        for i in reversed(range(len(deltas) - 1)):
            if self.activations[i] == "sigmoid":
                # calculate error delta_l = delta_{l+1} x w_{l+1} * sigmoid'(a_{l+1})
                deltas[i] = np.dot(deltas[i+1], self.weights[i+1].T) * self.sigmoid_derivative(activations[i+1])
            elif self.activations[i] == "linear":
                deltas[i] = np.dot(deltas[i+1], self.weights[i+1].T)
        
        L = len(self.weights)
        weights_gradient = [None] * L
        biases_gradient = [None] * L
        # calculate partial derevatives of cost function
        for i in range(L):
            # activations array is longer (so activations[l] in reality is a_{l-1})
            weights_gradient[i] = np.dot(activations[i].T, deltas[i])
            biases_gradient[i] = np.sum(deltas[i], axis=0)
            
        return weights_gradient, biases_gradient
        
    def update_weights(self, X, y, learning_rate, optimize=None, optimize_param=0.9):
        """
        updates weights using gradient descent
        """
        m = len(X)
        weights_gradient, biases_gradient = self.backward(X, y)
        for i in range(len(self.weights)):
            
            if optimize is None:
                self.weights[i] = self.weights[i] - (learning_rate/m) * weights_gradient[i]
                self.biases[i] = self.biases[i] - (learning_rate/m) * biases_gradient[i]
            
            elif optimize == 'moment':
                self.velocities_weights[i] = weights_gradient[i] + self.velocities_weights[i] * optimize_param
                self.velocities_biases[i] = biases_gradient[i] + self.velocities_biases[i] * optimize_param
            
                self.weights[i] = self.weights[i] - (learning_rate/m) * self.velocities_weights[i]
                self.biases[i] = self.biases[i] - (learning_rate/m) * self.velocities_biases[i]            
            
            elif optimize == 'rmsprop':
                self.velocities_weights[i] = optimize_param * self.velocities_weights[i] + (1-optimize_param) * (weights_gradient[i]**2)
                self.velocities_biases[i] = optimize_param * self.velocities_biases[i] + (1-optimize_param) * (biases_gradient[i]**2)
                
                self.weights[i] = self.weights[i] - (learning_rate/m) * (weights_gradient[i]/np.sqrt(self.velocities_weights[i]))
                self.biases[i] = self.biases[i] - (learning_rate/m) * (biases_gradient[i]/np.sqrt(self.velocities_biases[i]))
    
    def create_batches(self, X, y, batch_size):
        N = len(X)
        combined_data = np.array(list(zip(X, y)))
        np.random.shuffle(combined_data)

        X_shuffled = np.array(list(zip(*combined_data))[0])
        y_shuffled = np.array(list(zip(*combined_data))[1])

        X_mini_batches = [X_shuffled[k:k+batch_size] for k in range(0, N, batch_size)]
        y_mini_batches = [y_shuffled[k:k+batch_size] for k in range(0, N, batch_size)]
        return X_mini_batches, y_mini_batches
        
    def train(self, X, y, learning_rate=0.001, epochs=10000, batch_size=None, return_history=False, 
              optimize=None, optimize_param=0.9,
              X_test=None, y_test=None, cutoff=None, resize=False, denormalize=None, info_interval=500, mute_print=False):
        """
        To test and print MSE on testset, X_test and y_test need to be provided
        To set early stopping, provide cutoff (and test sets)
        denormalize: a tuple (mean, std) for denormalizing target for calculating mse
        info_interval: number of epochs between logging, set to None to turn off console output
        optimize: 'moment' or 'rmsprop'
        """
        assert optimize is None or optimize in ['moment', 'rmsprop'], f"optimize should be None or in ['moment', 'rmsprop']"
        
        test_mse = False
        if X_test is not None and y_test is not None:
            test_mse = True
        early_stopping = False
        if test_mse and cutoff is not None:
            early_stopping = True
        
        if resize:
            X = X.to_numpy().reshape(-1, 1)
            y = y.to_numpy().reshape(-1, 1)
            if test_mse:
                X_test = X_test.to_numpy().reshape(-1, 1)
                y_test = y_test.to_numpy().reshape(-1, 1)
            
        if batch_size is None:
            batch_size = len(X)
        
        y_mse = y
        if denormalize is not None:
            y_mse = destandardize_data(y, denormalize)
            
        history = History()
        
        for epoch in range(1, epochs+1):
            
            if batch_size < len(X):
                batches_x, batches_y = self.create_batches(X, y, batch_size)
                for i in range(len(batches_x)):
                    self.update_weights(batches_x[i], batches_y[i], learning_rate, optimize, optimize_param)
            else:
                self.update_weights(X, y, learning_rate, optimize, optimize_param)
            
            if info_interval is not None and epoch % info_interval == 0:
                loss = self.mse(X, y_mse, denormalize=denormalize)    
                history.loss.append(loss)
                history.loss_epochs.append(epoch)
                training_info = f"Epoch {epoch}: Loss = {round(loss, 3)}"
                if test_mse:
                    loss_test = self.mse(X_test, y_test, denormalize=denormalize)
                    training_info += f" Test Loss = {round(loss_test, 3)}"
                if not mute_print:
                    print(training_info)
            
            history.weights.append(copy.deepcopy(self.weights))
            history.biases.append(copy.deepcopy(self.biases))
            
            if early_stopping:
                loss_es = self.mse(X_test, y_test, denormalize=denormalize)
                if loss_es < cutoff:
                    loss = self.mse(X, y_mse, denormalize=denormalize)    
                    training_info = f"Epoch {epoch}: Loss = {round(loss, 3)}"
                    loss_test = self.mse(X_test, y_test, denormalize=denormalize)
                    training_info += f" Test Loss = {round(loss_test, 3)}"
                    print(training_info)
                    break
        
        if return_history:
            return history

def standardize_data(X):
    """
    returns:
    X_new - standardized X
    a tuple (mean, std) - normal distribution parameters from X for destandarizing
    """
    mean = np.mean(X, axis=0)
    std = np.std(X, axis=0)
    X_new = (X - mean) / std
    return X_new, (mean, std)

def destandardize_data(X, parameters):
    """parameters: a tuple (mean, std)"""
    return X * parameters[1] + parameters[0]

    
class History:
    """
    Class which attributes are weights from all training epochs 
    and loss for chosen loss_epochs (usually epochs with some interval)
    """
    
    def __init__(self):
        self.weights = []
        self.biases = []
        self.loss = []
        self.test_loss = []
        self.loss_epochs = []
    
    def plot_weights(self, layer, bias=False, return_plot=False):
        """
        layer - integer, index of weights vector
        if to plot bias instead of weights 
        """
        weights = []
        weights_type = 'Weights'
        if bias:
            weights_type = 'Biases'
            for epoch in self.biases:
                weights.append(epoch[layer].flatten())
        else:
            for epoch in self.weights:
                weights.append(epoch[layer].flatten())

        weights = np.array(weights)
        for i in range(weights.shape[1]):
            w_y = weights[:,i]
            plt.plot(range(len(self.weights)), w_y)
            
        plt.xlabel('Epochs')
        plt.title(f'{weights_type} values vs epochs at layer {layer}')
        if return_plot:
            return plt
        else:
            plt.show()
        
    def plot_loss(self, test=False, return_plot=False):
        if test:
            plt.plot(self.loss_epochs, self.test_loss)
            plt.title('Test loss history')
        else:
            plt.plot(self.loss_epochs, self.loss)
            plt.title('Training loss history')
        plt.xlabel('Epochs')
        plt.ylabel('MSE')
#         if return_plot:
#             return plt
#         else:
#             plt.show()

# %% [markdown]
# ## Kryteria MSE

# %% [markdown]
# ### Zbiór square-large

# %%
square_large_test = pd.read_csv("../dane/regression/square-large-test.csv", index_col=0)
square_large_train = pd.read_csv("../dane/regression/square-large-training.csv", index_col=0)

# %%
mlp = NeuralNetwork([1,10,1])
y_norm, parameters = standardize_data(square_simple_train['y'])
history = mlp.train(square_large_train['x'], y_norm, learning_rate=0.1, epochs=1000000, batch_size=50, return_history=True, resize=True,
                   X_test=square_large_test['x'], y_test=square_large_test['y'], cutoff=1, denormalize=parameters, info_interval=100,
                   optimize='rmsprop', optimize_param=0.9)
# Out:
# Epoch 100: Loss = 5775.864 Test Loss = 11278.879
# Epoch 200: Loss = 1418.55 Test Loss = 4308.381
# Epoch 300: Loss = 102.581 Test Loss = 990.17
# Epoch 400: Loss = 30.234 Test Loss = 457.296
# Epoch 500: Loss = 8.765 Test Loss = 219.607
# Epoch 600: Loss = 2.971 Test Loss = 128.837
# Epoch 700: Loss = 1.803 Test Loss = 96.495
# Epoch 800: Loss = 1.444 Test Loss = 83.957
# Epoch 900: Loss = 1.246 Test Loss = 76.967
# Epoch 1000: Loss = 1.237 Test Loss = 78.318
# Epoch 1100: Loss = 1.453 Test Loss = 70.398
# Epoch 1200: Loss = 1.121 Test Loss = 70.216
# Epoch 1300: Loss = 1.153 Test Loss = 71.54
# Epoch 1400: Loss = 0.938 Test Loss = 64.711
# Epoch 1500: Loss = 1.12 Test Loss = 62.151
# Epoch 1600: Loss = 1.1 Test Loss = 63.6
# Epoch 1700: Loss = 0.764 Test Loss = 61.949
# Epoch 1800: Loss = 0.713 Test Loss = 57.893
# Epoch 1900: Loss = 0.919 Test Loss = 54.579
# Epoch 2000: Loss = 0.664 Test Loss = 54.024
# Epoch 2100: Loss = 0.993 Test Loss = 52.717
# Epoch 2200: Loss = 0.598 Test Loss = 51.154
# Epoch 2300: Loss = 0.652 Test Loss = 50.46
# Epoch 2400: Loss = 0.553 Test Loss = 49.597
# Epoch 2500: Loss = 0.8 Test Loss = 46.05
# Epoch 2600: Loss = 0.517 Test Loss = 45.31
# Epoch 2700: Loss = 0.486 Test Loss = 45.708
# Epoch 2800: Loss = 0.531 Test Loss = 43.725
# Epoch 2900: Loss = 0.599 Test Loss = 41.321
# Epoch 3000: Loss = 0.681 Test Loss = 43.157
# Epoch 3100: Loss = 0.423 Test Loss = 41.046
# Epoch 3200: Loss = 0.432 Test Loss = 41.281
# Epoch 3300: Loss = 0.732 Test Loss = 35.379
# Epoch 3400: Loss = 0.407 Test Loss = 38.218
# Epoch 3500: Loss = 0.409 Test Loss = 38.158
# Epoch 3600: Loss = 0.807 Test Loss = 38.764
# Epoch 3700: Loss = 0.493 Test Loss = 37.034
# Epoch 3800: Loss = 0.357 Test Loss = 33.746
# Epoch 3900: Loss = 0.491 Test Loss = 35.628
# Epoch 4000: Loss = 0.311 Test Loss = 31.306
# Epoch 4100: Loss = 0.299 Test Loss = 30.413
# Epoch 4200: Loss = 0.324 Test Loss = 32.013
# Epoch 4300: Loss = 0.369 Test Loss = 28.901
# Epoch 4400: Loss = 0.404 Test Loss = 27.577
# Epoch 4500: Loss = 0.268 Test Loss = 27.246
# Epoch 4600: Loss = 0.363 Test Loss = 25.096
# Epoch 4700: Loss = 0.453 Test Loss = 27.884
# Epoch 4800: Loss = 0.531 Test Loss = 28.183
# Epoch 4900: Loss = 0.389 Test Loss = 23.957
# Epoch 5000: Loss = 0.27 Test Loss = 25.253
# Epoch 5100: Loss = 0.46 Test Loss = 25.687
# Epoch 5200: Loss = 0.218 Test Loss = 22.854
# Epoch 5300: Loss = 0.228 Test Loss = 21.555
# Epoch 5400: Loss = 0.28 Test Loss = 20.742
# Epoch 5500: Loss = 0.446 Test Loss = 20.669
# Epoch 5600: Loss = 0.251 Test Loss = 21.828
# Epoch 5700: Loss = 0.274 Test Loss = 21.429
# Epoch 5800: Loss = 0.2 Test Loss = 19.823
# Epoch 5900: Loss = 0.471 Test Loss = 20.71
# Epoch 6000: Loss = 0.275 Test Loss = 19.719
# Epoch 6100: Loss = 0.168 Test Loss = 17.336
# Epoch 6200: Loss = 0.168 Test Loss = 16.557
# Epoch 6300: Loss = 0.151 Test Loss = 16.116
# Epoch 6400: Loss = 0.18 Test Loss = 16.599
# Epoch 6500: Loss = 0.325 Test Loss = 17.063
# Epoch 6600: Loss = 0.138 Test Loss = 15.398
# Epoch 6700: Loss = 0.232 Test Loss = 15.246
# Epoch 6800: Loss = 0.167 Test Loss = 14.598
# Epoch 6900: Loss = 0.458 Test Loss = 14.923
# Epoch 7000: Loss = 0.115 Test Loss = 12.175
# Epoch 7100: Loss = 0.15 Test Loss = 12.797
# Epoch 7200: Loss = 0.173 Test Loss = 12.499
# Epoch 7300: Loss = 0.087 Test Loss = 10.735
# Epoch 7400: Loss = 0.168 Test Loss = 9.643
# Epoch 7500: Loss = 0.197 Test Loss = 8.971
# Epoch 7600: Loss = 0.073 Test Loss = 9.263
# Epoch 7700: Loss = 0.636 Test Loss = 10.77
# Epoch 7800: Loss = 0.199 Test Loss = 9.594
# Epoch 7900: Loss = 0.17 Test Loss = 7.576
# Epoch 8000: Loss = 0.303 Test Loss = 9.138
# Epoch 8100: Loss = 0.052 Test Loss = 7.425
# Epoch 8200: Loss = 0.134 Test Loss = 8.425
# Epoch 8300: Loss = 0.114 Test Loss = 7.992
# Epoch 8400: Loss = 0.06 Test Loss = 7.296
# Epoch 8500: Loss = 0.171 Test Loss = 6.607
# Epoch 8600: Loss = 0.164 Test Loss = 7.628
# Epoch 8700: Loss = 0.114 Test Loss = 6.212
# Epoch 8800: Loss = 0.146 Test Loss = 7.316
# Epoch 8900: Loss = 0.088 Test Loss = 6.455
# Epoch 9000: Loss = 0.11 Test Loss = 6.617
# Epoch 9100: Loss = 0.194 Test Loss = 7.158
# Epoch 9200: Loss = 0.08 Test Loss = 7.138
# Epoch 9300: Loss = 0.08 Test Loss = 6.94
# Epoch 9400: Loss = 0.106 Test Loss = 7.251
# Epoch 9500: Loss = 0.21 Test Loss = 5.738
# Epoch 9600: Loss = 0.555 Test Loss = 5.858
# Epoch 9700: Loss = 0.117 Test Loss = 7.299
# Epoch 9800: Loss = 0.084 Test Loss = 7.108
# Epoch 9900: Loss = 0.052 Test Loss = 6.311
# Epoch 10000: Loss = 0.146 Test Loss = 6.253
# Epoch 10100: Loss = 0.152 Test Loss = 6.339
# Epoch 10200: Loss = 0.23 Test Loss = 7.764
# Epoch 10300: Loss = 0.055 Test Loss = 6.975
# Epoch 10400: Loss = 0.221 Test Loss = 7.601
# Epoch 10500: Loss = 0.192 Test Loss = 7.669
# Epoch 10600: Loss = 0.469 Test Loss = 5.725
# Epoch 10700: Loss = 0.112 Test Loss = 7.206
# Epoch 10800: Loss = 0.078 Test Loss = 6.085
# Epoch 10900: Loss = 0.174 Test Loss = 7.807
# Epoch 11000: Loss = 0.124 Test Loss = 7.433
# Epoch 11100: Loss = 0.115 Test Loss = 6.317
# Epoch 11200: Loss = 0.184 Test Loss = 7.662
# Epoch 11300: Loss = 0.226 Test Loss = 6.02
# Epoch 11400: Loss = 0.113 Test Loss = 7.368
# Epoch 11500: Loss = 0.207 Test Loss = 7.56
# Epoch 11600: Loss = 0.1 Test Loss = 7.15
# Epoch 11700: Loss = 0.186 Test Loss = 7.406
# Epoch 11800: Loss = 0.332 Test Loss = 6.018
# Epoch 11900: Loss = 0.193 Test Loss = 7.361
# Epoch 12000: Loss = 0.349 Test Loss = 6.341
# Epoch 12100: Loss = 0.202 Test Loss = 6.529
# Epoch 12200: Loss = 0.046 Test Loss = 7.304
# Epoch 12300: Loss = 0.266 Test Loss = 8.177
# Epoch 12400: Loss = 0.159 Test Loss = 7.462
# Epoch 12500: Loss = 0.05 Test Loss = 6.399
# Epoch 12600: Loss = 0.106 Test Loss = 6.588
# Epoch 12700: Loss = 0.106 Test Loss = 7.682
# Epoch 12800: Loss = 0.17 Test Loss = 7.927
# Epoch 12900: Loss = 0.087 Test Loss = 7.483
# Epoch 13000: Loss = 0.261 Test Loss = 8.509
# Epoch 13100: Loss = 0.063 Test Loss = 7.564
# Epoch 13200: Loss = 0.18 Test Loss = 7.694
# Epoch 13300: Loss = 0.078 Test Loss = 7.352
# Epoch 13400: Loss = 0.215 Test Loss = 6.419
# Epoch 13500: Loss = 0.097 Test Loss = 7.794
# Epoch 13600: Loss = 0.131 Test Loss = 7.517
# Epoch 13700: Loss = 0.338 Test Loss = 6.155
# Epoch 13800: Loss = 0.086 Test Loss = 7.51
# Epoch 13900: Loss = 0.189 Test Loss = 6.678
# Epoch 14000: Loss = 0.238 Test Loss = 8.148
# Epoch 14100: Loss = 0.323 Test Loss = 6.188
# Epoch 14200: Loss = 0.445 Test Loss = 8.879
# Epoch 14300: Loss = 0.028 Test Loss = 6.948
# Epoch 14400: Loss = 0.097 Test Loss = 6.658
# Epoch 14500: Loss = 0.106 Test Loss = 6.209
# Epoch 14600: Loss = 0.276 Test Loss = 6.36
# Epoch 14700: Loss = 0.184 Test Loss = 8.349
# Epoch 14800: Loss = 0.214 Test Loss = 6.378
# Epoch 14900: Loss = 0.072 Test Loss = 6.605
# Epoch 15000: Loss = 0.161 Test Loss = 8.105
# Epoch 15100: Loss = 0.075 Test Loss = 7.515
# Epoch 15200: Loss = 0.089 Test Loss = 6.521
# Epoch 15300: Loss = 0.305 Test Loss = 6.606
# Epoch 15400: Loss = 0.04 Test Loss = 6.78
# Epoch 15500: Loss = 0.12 Test Loss = 8.02
# Epoch 15600: Loss = 0.253 Test Loss = 8.267
# Epoch 15700: Loss = 0.158 Test Loss = 7.814
# Epoch 15800: Loss = 0.243 Test Loss = 6.412
# Epoch 15900: Loss = 0.072 Test Loss = 6.704
# Epoch 16000: Loss = 0.151 Test Loss = 7.823
# Epoch 16100: Loss = 0.524 Test Loss = 8.643
# Epoch 16200: Loss = 0.241 Test Loss = 8.238
# Epoch 16300: Loss = 0.025 Test Loss = 6.989
# Epoch 16400: Loss = 0.252 Test Loss = 6.571
# Epoch 16500: Loss = 0.195 Test Loss = 6.126
# Epoch 16600: Loss = 0.175 Test Loss = 6.132
# Epoch 16700: Loss = 0.142 Test Loss = 8.12
# Epoch 16800: Loss = 0.059 Test Loss = 7.728
# Epoch 16900: Loss = 0.12 Test Loss = 7.57
# Epoch 17000: Loss = 0.07 Test Loss = 7.576
# Epoch 17100: Loss = 0.022 Test Loss = 6.846
# Epoch 17200: Loss = 0.075 Test Loss = 6.703
# Epoch 17300: Loss = 0.163 Test Loss = 7.951
# Epoch 17400: Loss = 0.133 Test Loss = 7.852
# Epoch 17500: Loss = 0.348 Test Loss = 6.478
# Epoch 17600: Loss = 0.19 Test Loss = 8.094
# Epoch 17700: Loss = 0.216 Test Loss = 8.134
# Epoch 17800: Loss = 0.152 Test Loss = 6.285
# Epoch 17900: Loss = 0.211 Test Loss = 5.874
# Epoch 18000: Loss = 0.284 Test Loss = 5.981
# Epoch 18100: Loss = 0.121 Test Loss = 6.449
# Epoch 18200: Loss = 0.131 Test Loss = 6.285
# Epoch 18300: Loss = 0.323 Test Loss = 8.278
# Epoch 18400: Loss = 0.125 Test Loss = 7.748
# Epoch 18500: Loss = 0.294 Test Loss = 8.227
# Epoch 18600: Loss = 0.179 Test Loss = 6.375
# Epoch 18700: Loss = 0.162 Test Loss = 6.298
# Epoch 18800: Loss = 0.131 Test Loss = 7.316
# Epoch 18900: Loss = 0.132 Test Loss = 7.927
# Epoch 19000: Loss = 0.084 Test Loss = 7.453
# Epoch 19100: Loss = 0.173 Test Loss = 6.141
# Epoch 19200: Loss = 0.056 Test Loss = 6.213
# Epoch 19300: Loss = 0.2 Test Loss = 6.064
# Epoch 19400: Loss = 0.101 Test Loss = 6.327
# Epoch 19500: Loss = 0.119 Test Loss = 6.421
# Epoch 19600: Loss = 0.266 Test Loss = 6.616
# Epoch 19700: Loss = 0.15 Test Loss = 6.046
# Epoch 19800: Loss = 0.155 Test Loss = 6.014
# Epoch 19900: Loss = 0.111 Test Loss = 6.521
# Epoch 20000: Loss = 0.183 Test Loss = 6.345
# Epoch 20100: Loss = 0.098 Test Loss = 6.322
# Epoch 20200: Loss = 0.116 Test Loss = 6.158
# Epoch 20300: Loss = 0.308 Test Loss = 5.912
# Epoch 20400: Loss = 0.138 Test Loss = 6.364
# Epoch 20500: Loss = 0.077 Test Loss = 6.135
# Epoch 20600: Loss = 0.132 Test Loss = 6.267
# Epoch 20700: Loss = 0.247 Test Loss = 5.952
# Epoch 20800: Loss = 0.19 Test Loss = 7.26
# Epoch 20900: Loss = 0.104 Test Loss = 7.53
# Epoch 21000: Loss = 0.181 Test Loss = 7.601
# Epoch 21100: Loss = 0.132 Test Loss = 7.38
# Epoch 21200: Loss = 0.135 Test Loss = 7.45
# Epoch 21300: Loss = 0.085 Test Loss = 6.068
# Epoch 21400: Loss = 0.134 Test Loss = 7.464
# Epoch 21500: Loss = 0.099 Test Loss = 7.264
# Epoch 21600: Loss = 0.197 Test Loss = 7.727
# Epoch 21700: Loss = 0.133 Test Loss = 7.187
# Epoch 21800: Loss = 0.139 Test Loss = 5.608
# Epoch 21900: Loss = 0.094 Test Loss = 7.41
# Epoch 22000: Loss = 0.132 Test Loss = 7.218
# Epoch 22100: Loss = 0.03 Test Loss = 6.96
# Epoch 22200: Loss = 0.187 Test Loss = 7.216
# Epoch 22300: Loss = 0.169 Test Loss = 7.461
# Epoch 22400: Loss = 0.091 Test Loss = 7.271
# Epoch 22500: Loss = 0.147 Test Loss = 7.007
# Epoch 22600: Loss = 0.039 Test Loss = 6.826
# Epoch 22700: Loss = 0.157 Test Loss = 7.087
# Epoch 22800: Loss = 0.125 Test Loss = 5.98
# Epoch 22900: Loss = 0.106 Test Loss = 5.888
# Epoch 23000: Loss = 0.255 Test Loss = 5.782
# Epoch 23100: Loss = 0.082 Test Loss = 5.685
# Epoch 23200: Loss = 0.329 Test Loss = 5.968
# Epoch 23300: Loss = 0.06 Test Loss = 5.906
# Epoch 23400: Loss = 0.182 Test Loss = 7.09
# Epoch 23500: Loss = 0.125 Test Loss = 7.279
# Epoch 23600: Loss = 0.087 Test Loss = 6.732
# Epoch 23700: Loss = 0.248 Test Loss = 7.524
# Epoch 23800: Loss = 0.223 Test Loss = 7.172
# Epoch 23900: Loss = 0.165 Test Loss = 7.483
# Epoch 24000: Loss = 0.13 Test Loss = 6.943
# Epoch 24100: Loss = 0.139 Test Loss = 6.938
# Epoch 24200: Loss = 0.083 Test Loss = 5.462
# Epoch 24300: Loss = 0.359 Test Loss = 5.414
# Epoch 24400: Loss = 0.121 Test Loss = 5.915
# Epoch 24500: Loss = 0.06 Test Loss = 6.613
# Epoch 24600: Loss = 0.212 Test Loss = 6.877
# Epoch 24700: Loss = 0.298 Test Loss = 7.191
# Epoch 24800: Loss = 0.208 Test Loss = 5.597
# Epoch 24900: Loss = 0.131 Test Loss = 5.517
# Epoch 25000: Loss = 0.105 Test Loss = 5.737
# Epoch 25100: Loss = 0.199 Test Loss = 5.699
# Epoch 25200: Loss = 0.018 Test Loss = 5.929
# Epoch 25300: Loss = 0.085 Test Loss = 5.478
# Epoch 25400: Loss = 0.116 Test Loss = 5.48
# Epoch 25500: Loss = 0.123 Test Loss = 5.674
# Epoch 25600: Loss = 0.242 Test Loss = 5.634
# Epoch 25700: Loss = 0.253 Test Loss = 5.671
# Epoch 25800: Loss = 0.087 Test Loss = 5.358
# Epoch 25900: Loss = 0.132 Test Loss = 5.633
# Epoch 26000: Loss = 0.139 Test Loss = 5.441
# Epoch 26100: Loss = 0.117 Test Loss = 5.346
# Epoch 26200: Loss = 0.15 Test Loss = 5.141
# Epoch 26300: Loss = 0.152 Test Loss = 5.664
# Epoch 26400: Loss = 0.164 Test Loss = 5.559
# Epoch 26500: Loss = 0.043 Test Loss = 5.645
# Epoch 26600: Loss = 0.251 Test Loss = 5.367
# Epoch 26700: Loss = 0.141 Test Loss = 5.118
# Epoch 26800: Loss = 0.133 Test Loss = 5.548
# Epoch 26900: Loss = 0.095 Test Loss = 5.0
# Epoch 27000: Loss = 0.182 Test Loss = 6.845
# Epoch 27100: Loss = 0.073 Test Loss = 5.483
# Epoch 27200: Loss = 0.078 Test Loss = 5.44
# Epoch 27300: Loss = 0.109 Test Loss = 5.145
# Epoch 27400: Loss = 0.134 Test Loss = 6.667
# Epoch 27500: Loss = 0.064 Test Loss = 6.068
# Epoch 27600: Loss = 0.132 Test Loss = 6.004
# Epoch 27700: Loss = 0.046 Test Loss = 6.167
# Epoch 27800: Loss = 0.189 Test Loss = 5.369
# Epoch 27900: Loss = 0.144 Test Loss = 4.869
# Epoch 28000: Loss = 0.3 Test Loss = 4.841
# Epoch 28100: Loss = 0.087 Test Loss = 5.194
# Epoch 28200: Loss = 0.092 Test Loss = 4.861
# Epoch 28300: Loss = 0.084 Test Loss = 5.327
# Epoch 28400: Loss = 0.264 Test Loss = 4.774
# Epoch 28500: Loss = 0.137 Test Loss = 5.149
# Epoch 28600: Loss = 0.096 Test Loss = 5.19
# Epoch 28700: Loss = 0.191 Test Loss = 4.977
# Epoch 28800: Loss = 0.067 Test Loss = 5.187
# Epoch 28900: Loss = 0.098 Test Loss = 4.934
# Epoch 29000: Loss = 0.289 Test Loss = 5.353
# Epoch 29100: Loss = 0.077 Test Loss = 4.713
# Epoch 29200: Loss = 0.375 Test Loss = 4.861
# Epoch 29300: Loss = 0.043 Test Loss = 5.091
# Epoch 29400: Loss = 0.166 Test Loss = 4.866
# Epoch 29500: Loss = 0.156 Test Loss = 4.627
# Epoch 29600: Loss = 0.116 Test Loss = 5.097
# Epoch 29700: Loss = 0.104 Test Loss = 4.788
# Epoch 29800: Loss = 0.115 Test Loss = 6.202
# Epoch 29900: Loss = 0.111 Test Loss = 6.135
# Epoch 30000: Loss = 0.178 Test Loss = 6.043
# Epoch 30100: Loss = 0.137 Test Loss = 4.824
# Epoch 30200: Loss = 0.175 Test Loss = 4.738
# Epoch 30300: Loss = 0.237 Test Loss = 4.572
# Epoch 30400: Loss = 0.079 Test Loss = 4.871
# Epoch 30500: Loss = 0.269 Test Loss = 4.427
# Epoch 30600: Loss = 0.073 Test Loss = 4.751
# Epoch 30700: Loss = 0.156 Test Loss = 4.997
# Epoch 30800: Loss = 0.108 Test Loss = 4.564
# Epoch 30900: Loss = 0.153 Test Loss = 5.972
# Epoch 31000: Loss = 0.101 Test Loss = 6.114
# Epoch 31100: Loss = 0.208 Test Loss = 6.271
# Epoch 31200: Loss = 0.235 Test Loss = 6.082
# Epoch 31300: Loss = 0.28 Test Loss = 6.013
# Epoch 31400: Loss = 0.233 Test Loss = 6.053
# Epoch 31500: Loss = 0.245 Test Loss = 6.58
# Epoch 31600: Loss = 0.09 Test Loss = 5.579
# Epoch 31700: Loss = 0.122 Test Loss = 4.532
# Epoch 31800: Loss = 0.132 Test Loss = 4.203
# Epoch 31900: Loss = 0.207 Test Loss = 6.233
# Epoch 32000: Loss = 0.269 Test Loss = 5.683
# Epoch 32100: Loss = 0.174 Test Loss = 5.774
# Epoch 32200: Loss = 0.173 Test Loss = 5.809
# Epoch 32300: Loss = 0.165 Test Loss = 5.621
# Epoch 32400: Loss = 0.11 Test Loss = 5.862
# Epoch 32500: Loss = 0.255 Test Loss = 6.167
# Epoch 32600: Loss = 0.245 Test Loss = 5.817
# Epoch 32700: Loss = 0.077 Test Loss = 4.729
# Epoch 32800: Loss = 0.1 Test Loss = 4.349
# Epoch 32900: Loss = 0.077 Test Loss = 4.524
# Epoch 33000: Loss = 0.071 Test Loss = 4.278
# Epoch 33100: Loss = 0.076 Test Loss = 4.612
# Epoch 33200: Loss = 0.204 Test Loss = 4.367
# Epoch 33300: Loss = 0.197 Test Loss = 4.08
# Epoch 33400: Loss = 0.251 Test Loss = 4.11
# Epoch 33500: Loss = 0.18 Test Loss = 4.026
# Epoch 33600: Loss = 0.05 Test Loss = 4.235
# Epoch 33700: Loss = 0.11 Test Loss = 4.225
# Epoch 33800: Loss = 0.198 Test Loss = 4.164
# Epoch 33900: Loss = 0.078 Test Loss = 4.092
# Epoch 34000: Loss = 0.347 Test Loss = 3.985
# Epoch 34100: Loss = 0.213 Test Loss = 4.221
# Epoch 34200: Loss = 0.119 Test Loss = 4.122
# Epoch 34300: Loss = 0.186 Test Loss = 4.098
# Epoch 34400: Loss = 0.14 Test Loss = 3.929
# Epoch 34500: Loss = 0.081 Test Loss = 4.0
# Epoch 34600: Loss = 0.3 Test Loss = 4.076
# Epoch 34700: Loss = 0.088 Test Loss = 4.092
# Epoch 34800: Loss = 0.115 Test Loss = 4.051
# Epoch 34900: Loss = 0.165 Test Loss = 4.32
# Epoch 35000: Loss = 0.071 Test Loss = 4.027
# Epoch 35100: Loss = 0.087 Test Loss = 4.198
# Epoch 35200: Loss = 0.146 Test Loss = 3.928
# Epoch 35300: Loss = 0.138 Test Loss = 4.109
# Epoch 35400: Loss = 0.317 Test Loss = 3.924
# Epoch 35500: Loss = 0.11 Test Loss = 3.952
# Epoch 35600: Loss = 0.271 Test Loss = 3.683
# Epoch 35700: Loss = 0.197 Test Loss = 4.165
# Epoch 35800: Loss = 0.135 Test Loss = 3.863
# Epoch 35900: Loss = 0.081 Test Loss = 4.032
# Epoch 36000: Loss = 0.246 Test Loss = 3.923
# Epoch 36100: Loss = 0.278 Test Loss = 3.642
# Epoch 36200: Loss = 0.091 Test Loss = 3.891
# Epoch 36300: Loss = 0.192 Test Loss = 3.917
# Epoch 36400: Loss = 0.091 Test Loss = 3.948
# Epoch 36500: Loss = 0.075 Test Loss = 3.816
# Epoch 36600: Loss = 0.316 Test Loss = 3.476
# Epoch 36700: Loss = 0.067 Test Loss = 3.876
# Epoch 36800: Loss = 0.233 Test Loss = 3.502
# Epoch 36900: Loss = 0.238 Test Loss = 3.746
# Epoch 37000: Loss = 0.069 Test Loss = 3.599
# Epoch 37100: Loss = 0.02 Test Loss = 3.838
# Epoch 37200: Loss = 0.146 Test Loss = 3.686
# Epoch 37300: Loss = 0.108 Test Loss = 3.683
# Epoch 37400: Loss = 0.299 Test Loss = 3.703
# Epoch 37500: Loss = 0.135 Test Loss = 3.656
# Epoch 37600: Loss = 0.156 Test Loss = 3.652
# Epoch 37700: Loss = 0.126 Test Loss = 3.655
# Epoch 37800: Loss = 0.098 Test Loss = 3.655
# Epoch 37900: Loss = 0.108 Test Loss = 3.555
# Epoch 38000: Loss = 0.131 Test Loss = 3.846
# Epoch 38100: Loss = 0.053 Test Loss = 3.665
# Epoch 38200: Loss = 0.05 Test Loss = 3.746
# Epoch 38300: Loss = 0.168 Test Loss = 3.574
# Epoch 38400: Loss = 0.176 Test Loss = 3.427
# Epoch 38500: Loss = 0.11 Test Loss = 3.606
# Epoch 38600: Loss = 0.072 Test Loss = 3.672
# Epoch 38700: Loss = 0.155 Test Loss = 3.275
# Epoch 38800: Loss = 0.07 Test Loss = 3.509
# Epoch 38900: Loss = 0.098 Test Loss = 3.319
# Epoch 39000: Loss = 0.229 Test Loss = 3.496
# Epoch 39100: Loss = 0.051 Test Loss = 3.636
# Epoch 39200: Loss = 0.029 Test Loss = 3.664
# Epoch 39300: Loss = 0.069 Test Loss = 3.51
# Epoch 39400: Loss = 0.024 Test Loss = 3.73
# Epoch 39500: Loss = 0.173 Test Loss = 3.268
# Epoch 39600: Loss = 0.098 Test Loss = 3.446
# Epoch 39700: Loss = 0.201 Test Loss = 3.425
# Epoch 39800: Loss = 0.105 Test Loss = 3.406
# Epoch 39900: Loss = 0.138 Test Loss = 3.326
# Epoch 40000: Loss = 0.12 Test Loss = 3.261
# Epoch 40100: Loss = 0.157 Test Loss = 3.351
# Epoch 40200: Loss = 0.237 Test Loss = 3.341
# Epoch 40300: Loss = 0.089 Test Loss = 3.415
# Epoch 40400: Loss = 0.137 Test Loss = 3.403
# Epoch 40500: Loss = 0.093 Test Loss = 3.125
# Epoch 40600: Loss = 0.215 Test Loss = 3.165
# Epoch 40700: Loss = 0.107 Test Loss = 3.21
# Epoch 40800: Loss = 0.164 Test Loss = 3.106
# Epoch 40900: Loss = 0.181 Test Loss = 3.067
# Epoch 41000: Loss = 0.205 Test Loss = 3.309
# Epoch 41100: Loss = 0.12 Test Loss = 3.215
# Epoch 41200: Loss = 0.207 Test Loss = 3.07
# Epoch 41300: Loss = 0.155 Test Loss = 3.23
# Epoch 41400: Loss = 0.089 Test Loss = 3.095
# Epoch 41500: Loss = 0.129 Test Loss = 3.21
# Epoch 41600: Loss = 0.084 Test Loss = 3.262
# Epoch 41700: Loss = 0.083 Test Loss = 3.143
# Epoch 41800: Loss = 0.111 Test Loss = 3.067
# Epoch 41900: Loss = 0.053 Test Loss = 3.181
# Epoch 42000: Loss = 0.142 Test Loss = 2.943
# Epoch 42100: Loss = 0.07 Test Loss = 2.961
# Epoch 42200: Loss = 0.205 Test Loss = 3.255
# Epoch 42300: Loss = 0.161 Test Loss = 2.963
# Epoch 42400: Loss = 0.245 Test Loss = 2.916
# Epoch 42500: Loss = 0.257 Test Loss = 3.053
# Epoch 42600: Loss = 0.092 Test Loss = 2.988
# Epoch 42700: Loss = 0.079 Test Loss = 2.948
# Epoch 42800: Loss = 0.082 Test Loss = 2.857
# Epoch 42900: Loss = 0.058 Test Loss = 3.027
# Epoch 43000: Loss = 0.058 Test Loss = 2.959
# Epoch 43100: Loss = 0.056 Test Loss = 2.847
# Epoch 43200: Loss = 0.062 Test Loss = 2.965
# Epoch 43300: Loss = 0.167 Test Loss = 2.703
# Epoch 43400: Loss = 0.117 Test Loss = 2.721
# Epoch 43500: Loss = 0.078 Test Loss = 2.814
# Epoch 43600: Loss = 0.1 Test Loss = 2.911
# Epoch 43700: Loss = 0.119 Test Loss = 2.874
# Epoch 43800: Loss = 0.147 Test Loss = 2.781
# Epoch 43900: Loss = 0.132 Test Loss = 2.867
# Epoch 44000: Loss = 0.124 Test Loss = 2.831
# Epoch 44100: Loss = 0.069 Test Loss = 2.755
# Epoch 44200: Loss = 0.256 Test Loss = 2.77
# Epoch 44300: Loss = 0.204 Test Loss = 2.746
# Epoch 44400: Loss = 0.148 Test Loss = 2.468
# Epoch 44500: Loss = 0.194 Test Loss = 2.591
# Epoch 44600: Loss = 0.26 Test Loss = 2.695
# Epoch 44700: Loss = 0.061 Test Loss = 2.793
# Epoch 44800: Loss = 0.185 Test Loss = 2.762
# Epoch 44900: Loss = 0.227 Test Loss = 2.816
# Epoch 45000: Loss = 0.11 Test Loss = 2.644
# Epoch 45100: Loss = 0.219 Test Loss = 2.901
# Epoch 45200: Loss = 0.239 Test Loss = 2.473
# Epoch 45300: Loss = 0.247 Test Loss = 2.504
# Epoch 45400: Loss = 0.147 Test Loss = 2.549
# Epoch 45500: Loss = 0.133 Test Loss = 2.493
# Epoch 45600: Loss = 0.12 Test Loss = 2.447
# Epoch 45700: Loss = 0.154 Test Loss = 2.506
# Epoch 45800: Loss = 0.123 Test Loss = 2.63
# Epoch 45900: Loss = 0.069 Test Loss = 2.59
# Epoch 46000: Loss = 0.242 Test Loss = 2.346
# Epoch 46100: Loss = 0.054 Test Loss = 2.528
# Epoch 46200: Loss = 0.152 Test Loss = 2.403
# Epoch 46300: Loss = 0.118 Test Loss = 2.57
# Epoch 46400: Loss = 0.112 Test Loss = 2.53
# Epoch 46500: Loss = 0.124 Test Loss = 2.341
# Epoch 46600: Loss = 0.071 Test Loss = 2.604
# Epoch 46700: Loss = 0.098 Test Loss = 2.432
# Epoch 46800: Loss = 0.113 Test Loss = 2.597
# Epoch 46900: Loss = 0.103 Test Loss = 2.377
# Epoch 47000: Loss = 0.157 Test Loss = 2.223
# Epoch 47100: Loss = 0.071 Test Loss = 2.287
# Epoch 47200: Loss = 0.054 Test Loss = 2.476
# Epoch 47300: Loss = 0.022 Test Loss = 2.462
# Epoch 47400: Loss = 0.068 Test Loss = 2.261
# Epoch 47500: Loss = 0.169 Test Loss = 2.246
# Epoch 47600: Loss = 0.28 Test Loss = 2.306
# Epoch 47700: Loss = 0.139 Test Loss = 2.32
# Epoch 47800: Loss = 0.129 Test Loss = 2.293
# Epoch 47900: Loss = 0.216 Test Loss = 2.447
# Epoch 48000: Loss = 0.148 Test Loss = 2.251
# Epoch 48100: Loss = 0.187 Test Loss = 2.072
# Epoch 48200: Loss = 0.335 Test Loss = 2.342
# Epoch 48300: Loss = 0.087 Test Loss = 2.37
# Epoch 48400: Loss = 0.117 Test Loss = 2.368
# Epoch 48500: Loss = 0.103 Test Loss = 2.246
# Epoch 48600: Loss = 0.336 Test Loss = 2.093
# Epoch 48700: Loss = 0.108 Test Loss = 2.023
# Epoch 48800: Loss = 0.089 Test Loss = 2.205
# Epoch 48900: Loss = 0.066 Test Loss = 2.38
# Epoch 49000: Loss = 0.145 Test Loss = 2.199
# Epoch 49100: Loss = 0.08 Test Loss = 2.087
# Epoch 49200: Loss = 0.044 Test Loss = 2.223
# Epoch 49300: Loss = 0.214 Test Loss = 2.232
# Epoch 49400: Loss = 0.121 Test Loss = 1.994
# Epoch 49500: Loss = 0.103 Test Loss = 2.026
# Epoch 49600: Loss = 0.108 Test Loss = 2.003
# Epoch 49700: Loss = 0.087 Test Loss = 2.243
# Epoch 49800: Loss = 0.224 Test Loss = 1.904
# Epoch 49900: Loss = 0.137 Test Loss = 1.951
# Epoch 50000: Loss = 0.311 Test Loss = 1.908
# Epoch 50100: Loss = 0.129 Test Loss = 2.023
# Epoch 50200: Loss = 0.151 Test Loss = 1.986
# Epoch 50300: Loss = 0.046 Test Loss = 2.103
# Epoch 50400: Loss = 0.213 Test Loss = 2.162
# Epoch 50500: Loss = 0.056 Test Loss = 2.139
# Epoch 50600: Loss = 0.28 Test Loss = 2.118
# Epoch 50700: Loss = 0.143 Test Loss = 1.917
# Epoch 50800: Loss = 0.151 Test Loss = 1.778
# Epoch 50900: Loss = 0.044 Test Loss = 2.062
# Epoch 51000: Loss = 0.095 Test Loss = 2.011
# Epoch 51100: Loss = 0.051 Test Loss = 2.219
# Epoch 51200: Loss = 0.08 Test Loss = 2.039
# Epoch 51300: Loss = 0.09 Test Loss = 1.976
# Epoch 51400: Loss = 0.197 Test Loss = 2.013
# Epoch 51500: Loss = 0.237 Test Loss = 1.798
# Epoch 51600: Loss = 0.205 Test Loss = 1.777
# Epoch 51700: Loss = 0.066 Test Loss = 1.925
# Epoch 51800: Loss = 0.051 Test Loss = 1.892
# Epoch 51900: Loss = 0.207 Test Loss = 1.808
# Epoch 52000: Loss = 0.233 Test Loss = 1.869
# Epoch 52100: Loss = 0.154 Test Loss = 1.751
# Epoch 52200: Loss = 0.208 Test Loss = 1.59
# Epoch 52300: Loss = 0.136 Test Loss = 1.865
# Epoch 52400: Loss = 0.112 Test Loss = 1.775
# Epoch 52500: Loss = 0.174 Test Loss = 1.515
# Epoch 52600: Loss = 0.123 Test Loss = 1.89
# Epoch 52700: Loss = 0.143 Test Loss = 1.677
# Epoch 52800: Loss = 0.121 Test Loss = 1.68
# Epoch 52900: Loss = 0.081 Test Loss = 1.759
# Epoch 53000: Loss = 0.118 Test Loss = 1.585
# Epoch 53100: Loss = 0.216 Test Loss = 1.674
# Epoch 53200: Loss = 0.168 Test Loss = 1.887
# Epoch 53300: Loss = 0.148 Test Loss = 1.688
# Epoch 53400: Loss = 0.212 Test Loss = 1.913
# Epoch 53500: Loss = 0.114 Test Loss = 1.595
# Epoch 53600: Loss = 0.139 Test Loss = 1.763
# Epoch 53700: Loss = 0.116 Test Loss = 1.695
# Epoch 53800: Loss = 0.051 Test Loss = 1.566
# Epoch 53900: Loss = 0.104 Test Loss = 1.686
# Epoch 54000: Loss = 0.19 Test Loss = 1.514
# Epoch 54100: Loss = 0.039 Test Loss = 1.625
# Epoch 54200: Loss = 0.124 Test Loss = 1.574
# Epoch 54300: Loss = 0.167 Test Loss = 1.672
# Epoch 54400: Loss = 0.109 Test Loss = 1.463
# Epoch 54500: Loss = 0.09 Test Loss = 1.61
# Epoch 54600: Loss = 0.152 Test Loss = 1.583
# Epoch 54700: Loss = 0.085 Test Loss = 1.45
# Epoch 54800: Loss = 0.037 Test Loss = 1.686
# Epoch 54900: Loss = 0.036 Test Loss = 1.576
# Epoch 55000: Loss = 0.106 Test Loss = 1.579
# Epoch 55100: Loss = 0.319 Test Loss = 1.315
# Epoch 55200: Loss = 0.108 Test Loss = 1.413
# Epoch 55300: Loss = 0.344 Test Loss = 1.489
# Epoch 55400: Loss = 0.052 Test Loss = 1.515
# Epoch 55500: Loss = 0.042 Test Loss = 1.55
# Epoch 55600: Loss = 0.237 Test Loss = 1.588
# Epoch 55700: Loss = 0.059 Test Loss = 1.502
# Epoch 55800: Loss = 0.089 Test Loss = 1.534
# Epoch 55900: Loss = 0.12 Test Loss = 1.398
# Epoch 56000: Loss = 0.213 Test Loss = 1.605
# Epoch 56006: Loss = 0.142 Test Loss = 0.997

# %%
print("MSE:", mlp.mse(square_simple['x'], square_simple['y'], resize=True, denormalize=parameters))
# Out:
# MSE: 0.9970608658810338

# %%
y_pred = mlp.predict(square_simple_test['x'].to_numpy().reshape(-1,1))
y_pred = destandardize_data(y_pred, parameters=parameters)
plt.scatter(square_simple_train['x'], square_simple_train['y'])
plt.scatter(square_simple_test['x'], square_simple_test['y'], s=12)
plt.scatter(square_simple_test['x'], y_pred, s=2)
plt.show()

# %% [markdown]
# ### Zbiór steps-large

# %%
steps_large_test = pd.read_csv("../dane/regression/steps-large-test.csv", index_col=0)
steps_large_train = pd.read_csv("../dane/regression/steps-large-training.csv", index_col=0)

# %%
mlp_steps = NeuralNetwork([1,5,5,1], initalization='he')
y_norm_steps, parameters_steps = standardize_data(steps_large_train['y'])
history_steps = mlp_steps.train(steps_large_train['x'], y_norm_steps, learning_rate=0.2, epochs=10000, return_history=True,
                                resize=True, X_test=steps_large_test['x'], y_test=steps_small_test['y'], cutoff=3,
                                denormalize=parameters_steps, info_interval=10, batch_size=10, optimize='rmsprop')
# Out:
# Epoch 10: Loss = 90.996 Test Loss = 82.794
# Epoch 20: Loss = 161.887 Test Loss = 162.485
# Epoch 30: Loss = 57.329 Test Loss = 70.766
# Epoch 40: Loss = 64.683 Test Loss = 86.866
# Epoch 50: Loss = 44.34 Test Loss = 39.355
# Epoch 60: Loss = 31.85 Test Loss = 35.654
# Epoch 70: Loss = 32.198 Test Loss = 34.767
# Epoch 80: Loss = 24.627 Test Loss = 23.471
# Epoch 90: Loss = 23.313 Test Loss = 18.808
# Epoch 100: Loss = 24.716 Test Loss = 15.113
# Epoch 110: Loss = 22.494 Test Loss = 15.73
# Epoch 120: Loss = 19.367 Test Loss = 13.309
# Epoch 130: Loss = 39.098 Test Loss = 39.52
# Epoch 140: Loss = 25.9 Test Loss = 21.772
# Epoch 150: Loss = 41.682 Test Loss = 19.498
# Epoch 160: Loss = 23.619 Test Loss = 13.151
# Epoch 170: Loss = 28.635 Test Loss = 32.841
# Epoch 180: Loss = 34.92 Test Loss = 44.575
# Epoch 190: Loss = 39.011 Test Loss = 16.7
# Epoch 200: Loss = 24.11 Test Loss = 17.622
# Epoch 210: Loss = 17.373 Test Loss = 15.729
# Epoch 220: Loss = 17.639 Test Loss = 10.338
# Epoch 230: Loss = 41.794 Test Loss = 45.619
# Epoch 240: Loss = 41.836 Test Loss = 39.374
# Epoch 250: Loss = 14.563 Test Loss = 10.502
# Epoch 260: Loss = 24.601 Test Loss = 22.752
# Epoch 270: Loss = 50.327 Test Loss = 68.83
# Epoch 280: Loss = 24.805 Test Loss = 27.991
# Epoch 290: Loss = 58.754 Test Loss = 40.395
# Epoch 300: Loss = 24.69 Test Loss = 11.355
# Epoch 310: Loss = 28.362 Test Loss = 25.493
# Epoch 320: Loss = 31.984 Test Loss = 14.983
# Epoch 330: Loss = 20.044 Test Loss = 20.28
# Epoch 340: Loss = 55.661 Test Loss = 45.121
# Epoch 350: Loss = 18.009 Test Loss = 15.767
# Epoch 360: Loss = 12.951 Test Loss = 9.031
# Epoch 370: Loss = 12.89 Test Loss = 9.344
# Epoch 380: Loss = 18.331 Test Loss = 20.972
# Epoch 390: Loss = 14.851 Test Loss = 10.147
# Epoch 400: Loss = 42.626 Test Loss = 43.397
# Epoch 410: Loss = 48.303 Test Loss = 48.059
# Epoch 420: Loss = 26.64 Test Loss = 20.081
# Epoch 430: Loss = 19.424 Test Loss = 10.949
# Epoch 440: Loss = 63.455 Test Loss = 81.814
# Epoch 450: Loss = 13.559 Test Loss = 12.333
# Epoch 460: Loss = 13.38 Test Loss = 8.114
# Epoch 470: Loss = 11.656 Test Loss = 9.722
# Epoch 480: Loss = 13.129 Test Loss = 9.985
# Epoch 490: Loss = 12.51 Test Loss = 14.046
# Epoch 500: Loss = 18.054 Test Loss = 16.556
# Epoch 510: Loss = 18.58 Test Loss = 17.259
# Epoch 520: Loss = 34.695 Test Loss = 26.709
# Epoch 530: Loss = 25.592 Test Loss = 16.892
# Epoch 540: Loss = 56.086 Test Loss = 46.17
# Epoch 550: Loss = 35.498 Test Loss = 28.666
# Epoch 560: Loss = 14.814 Test Loss = 14.062
# Epoch 570: Loss = 41.126 Test Loss = 21.113
# Epoch 580: Loss = 41.287 Test Loss = 34.647
# Epoch 590: Loss = 36.67 Test Loss = 45.57
# Epoch 600: Loss = 12.361 Test Loss = 9.849
# Epoch 610: Loss = 14.077 Test Loss = 12.119
# Epoch 620: Loss = 19.545 Test Loss = 19.85
# Epoch 630: Loss = 18.58 Test Loss = 15.594
# Epoch 640: Loss = 19.422 Test Loss = 16.052
# Epoch 650: Loss = 21.229 Test Loss = 15.241
# Epoch 660: Loss = 30.058 Test Loss = 19.523
# Epoch 670: Loss = 25.276 Test Loss = 24.22
# Epoch 680: Loss = 14.92 Test Loss = 18.762
# Epoch 690: Loss = 12.284 Test Loss = 12.501
# Epoch 700: Loss = 21.194 Test Loss = 15.881
# Epoch 710: Loss = 17.427 Test Loss = 11.081
# Epoch 720: Loss = 44.503 Test Loss = 39.349
# Epoch 730: Loss = 28.953 Test Loss = 16.853
# Epoch 740: Loss = 57.098 Test Loss = 54.359
# Epoch 750: Loss = 11.564 Test Loss = 14.789
# Epoch 760: Loss = 14.58 Test Loss = 14.283
# Epoch 770: Loss = 45.763 Test Loss = 42.775
# Epoch 780: Loss = 12.311 Test Loss = 10.326
# Epoch 790: Loss = 20.799 Test Loss = 11.619
# Epoch 800: Loss = 23.078 Test Loss = 17.965
# Epoch 810: Loss = 15.882 Test Loss = 9.392
# Epoch 820: Loss = 26.656 Test Loss = 8.504
# Epoch 830: Loss = 43.14 Test Loss = 43.949
# Epoch 840: Loss = 9.307 Test Loss = 8.36
# Epoch 850: Loss = 47.742 Test Loss = 35.712
# Epoch 860: Loss = 26.299 Test Loss = 11.936
# Epoch 870: Loss = 9.54 Test Loss = 3.826
# Epoch 880: Loss = 50.21 Test Loss = 37.001
# Epoch 890: Loss = 10.22 Test Loss = 6.695
# Epoch 900: Loss = 17.626 Test Loss = 15.697
# Epoch 910: Loss = 53.285 Test Loss = 27.247
# Epoch 920: Loss = 19.51 Test Loss = 10.921
# Epoch 930: Loss = 30.497 Test Loss = 37.728
# Epoch 940: Loss = 12.671 Test Loss = 10.712
# Epoch 950: Loss = 37.582 Test Loss = 21.919
# Epoch 960: Loss = 24.807 Test Loss = 17.562
# Epoch 970: Loss = 31.126 Test Loss = 32.697
# Epoch 980: Loss = 23.566 Test Loss = 9.852
# Epoch 990: Loss = 36.589 Test Loss = 30.052
# Epoch 1000: Loss = 23.141 Test Loss = 16.956
# Epoch 1010: Loss = 24.564 Test Loss = 19.378
# Epoch 1020: Loss = 24.95 Test Loss = 15.605
# Epoch 1030: Loss = 17.209 Test Loss = 17.144
# Epoch 1040: Loss = 7.608 Test Loss = 3.875
# Epoch 1050: Loss = 9.679 Test Loss = 14.691
# Epoch 1060: Loss = 21.173 Test Loss = 18.059
# Epoch 1070: Loss = 10.478 Test Loss = 4.987
# Epoch 1080: Loss = 27.162 Test Loss = 12.905
# Epoch 1090: Loss = 20.014 Test Loss = 22.089
# Epoch 1100: Loss = 51.551 Test Loss = 29.988
# Epoch 1110: Loss = 20.696 Test Loss = 12.542
# Epoch 1120: Loss = 22.857 Test Loss = 21.152
# Epoch 1130: Loss = 12.966 Test Loss = 13.579
# Epoch 1140: Loss = 16.3 Test Loss = 18.189
# Epoch 1150: Loss = 13.433 Test Loss = 10.862
# Epoch 1160: Loss = 30.324 Test Loss = 19.949
# Epoch 1170: Loss = 28.281 Test Loss = 20.495
# Epoch 1180: Loss = 31.197 Test Loss = 23.682
# Epoch 1190: Loss = 34.251 Test Loss = 41.84
# Epoch 1200: Loss = 21.723 Test Loss = 11.401
# Epoch 1210: Loss = 11.199 Test Loss = 11.117
# Epoch 1220: Loss = 19.265 Test Loss = 7.734
# Epoch 1230: Loss = 25.676 Test Loss = 12.18
# Epoch 1240: Loss = 20.683 Test Loss = 19.326
# Epoch 1250: Loss = 43.043 Test Loss = 38.831
# Epoch 1260: Loss = 23.737 Test Loss = 11.982
# Epoch 1270: Loss = 11.914 Test Loss = 4.836
# Epoch 1280: Loss = 10.135 Test Loss = 7.201
# Epoch 1290: Loss = 35.402 Test Loss = 26.376
# Epoch 1300: Loss = 18.402 Test Loss = 15.824
# Epoch 1310: Loss = 21.25 Test Loss = 15.336
# Epoch 1320: Loss = 17.253 Test Loss = 16.279
# Epoch 1330: Loss = 27.457 Test Loss = 31.734
# Epoch 1340: Loss = 12.783 Test Loss = 18.042
# Epoch 1350: Loss = 15.548 Test Loss = 15.381
# Epoch 1360: Loss = 23.562 Test Loss = 12.839
# Epoch 1370: Loss = 7.412 Test Loss = 9.551
# Epoch 1380: Loss = 20.111 Test Loss = 16.521
# Epoch 1390: Loss = 62.674 Test Loss = 53.739
# Epoch 1400: Loss = 61.028 Test Loss = 53.554
# Epoch 1410: Loss = 17.538 Test Loss = 10.687
# Epoch 1420: Loss = 15.966 Test Loss = 15.024
# Epoch 1430: Loss = 30.505 Test Loss = 19.603
# Epoch 1431: Loss = 7.552 Test Loss = 2.474

# %%
preds_steps = mlp_steps.predict(steps_large_test['x'].to_numpy().reshape(-1,1))
preds_steps_denorm = destandardize_data(preds_steps, parameters_steps)
print('Test MSE:', mlp_steps.mse(steps_large_test['x'], steps_large_test['y'], resize=True, denormalize=parameters_steps))
# Out:
# Test MSE: 2.4739037637283277

# %% [markdown]
# ### Zbiór multimodal-large

# %%
multimodal_test = pd.read_csv("../dane/regression/multimodal-large-test.csv", index_col=0).reset_index()
multimodal_train = pd.read_csv("../dane/regression/multimodal-large-training.csv", index_col=0).reset_index()

# %%
mlp_modal = NeuralNetwork([1,10,10,1], initalization='xavier')
y_norm_modal, parameters_modal = standardize_data(multimodal_train['y'])
history_modal = mlp_modal.train(multimodal_train['x'], y_norm_modal, learning_rate=1, epochs=100000, return_history=True,
                                resize=True, X_test=multimodal_test['x'], y_test=multimodal_test['y'], cutoff=30,
                                denormalize=parameters_modal, info_interval=1000)
# Out:
# Epoch 1000: Loss = 2072.824 Test Loss = 2061.447
# Epoch 2000: Loss = 1660.288 Test Loss = 1662.73
# Epoch 3000: Loss = 1593.629 Test Loss = 1601.314
# Epoch 4000: Loss = 1560.446 Test Loss = 1569.977
# Epoch 5000: Loss = 1535.542 Test Loss = 1546.294
# Epoch 6000: Loss = 1336.624 Test Loss = 1346.198
# Epoch 7000: Loss = 660.518 Test Loss = 688.293
# Epoch 8000: Loss = 565.986 Test Loss = 597.867
# Epoch 9000: Loss = 534.578 Test Loss = 566.206
# Epoch 10000: Loss = 511.731 Test Loss = 542.682
# Epoch 11000: Loss = 490.494 Test Loss = 520.97
# Epoch 12000: Loss = 492.542 Test Loss = 521.553
# Epoch 13000: Loss = 503.228 Test Loss = 529.168
# Epoch 14000: Loss = 503.387 Test Loss = 524.493
# Epoch 15000: Loss = 475.107 Test Loss = 490.142
# Epoch 16000: Loss = 420.17 Test Loss = 429.769
# Epoch 17000: Loss = 356.297 Test Loss = 362.666
# Epoch 18000: Loss = 293.359 Test Loss = 298.571
# Epoch 19000: Loss = 233.567 Test Loss = 238.743
# Epoch 20000: Loss = 180.17 Test Loss = 185.811
# Epoch 21000: Loss = 155.663 Test Loss = 161.252
# Epoch 22000: Loss = 140.505 Test Loss = 144.961
# Epoch 23000: Loss = 126.507 Test Loss = 129.827
# Epoch 24000: Loss = 113.767 Test Loss = 115.996
# Epoch 25000: Loss = 102.231 Test Loss = 103.452
# Epoch 26000: Loss = 91.741 Test Loss = 92.048
# Epoch 27000: Loss = 82.131 Test Loss = 81.608
# Epoch 28000: Loss = 73.289 Test Loss = 72.033
# Epoch 29000: Loss = 65.117 Test Loss = 63.253
# Epoch 30000: Loss = 57.493 Test Loss = 55.156
# Epoch 31000: Loss = 50.338 Test Loss = 47.652
# Epoch 32000: Loss = 43.683 Test Loss = 40.741
# Epoch 33000: Loss = 37.653 Test Loss = 34.518
# Epoch 34000: Loss = 32.385 Test Loss = 29.092
# Epoch 35000: Loss = 27.949 Test Loss = 24.516
# Epoch 36000: Loss = 24.323 Test Loss = 20.759
# Epoch 37000: Loss = 21.417 Test Loss = 17.728
# Epoch 38000: Loss = 19.109 Test Loss = 15.3
# Epoch 39000: Loss = 17.279 Test Loss = 13.357
# Epoch 40000: Loss = 15.823 Test Loss = 11.795
# Epoch 41000: Loss = 14.656 Test Loss = 10.529
# Epoch 42000: Loss = 13.711 Test Loss = 9.495
# Epoch 43000: Loss = 12.939 Test Loss = 8.642
# Epoch 44000: Loss = 12.303 Test Loss = 7.933
# Epoch 45000: Loss = 11.773 Test Loss = 7.337
# Epoch 46000: Loss = 11.328 Test Loss = 6.833
# Epoch 47000: Loss = 10.951 Test Loss = 6.404
# Epoch 48000: Loss = 10.63 Test Loss = 6.036
# Epoch 49000: Loss = 10.354 Test Loss = 5.718
# Epoch 50000: Loss = 10.116 Test Loss = 5.442
# Epoch 51000: Loss = 9.909 Test Loss = 5.201
# Epoch 52000: Loss = 9.727 Test Loss = 4.989
# Epoch 53000: Loss = 9.568 Test Loss = 4.803
# Epoch 54000: Loss = 9.427 Test Loss = 4.637
# Epoch 55000: Loss = 9.302 Test Loss = 4.49
# Epoch 56000: Loss = 9.19 Test Loss = 4.358
# Epoch 57000: Loss = 9.089 Test Loss = 4.24
# Epoch 58000: Loss = 8.999 Test Loss = 4.133
# Epoch 59000: Loss = 8.916 Test Loss = 4.036
# Epoch 59404: Loss = 8.885 Test Loss = 4.0

# %%
preds_modal = mlp_modal.predict(multimodal_test['x'].to_numpy().reshape(-1,1))
preds_modal_denorm = destandardize_data(preds_modal, parameters_modal)
plt.scatter(multimodal_test['x'], multimodal_test['y'])
plt.scatter(multimodal_test['x'], preds_modal_denorm, s=5)
print('Test MSE:', mlp_modal.mse(multimodal_test['x'], multimodal_test['y'], resize=True, denormalize=parameters_modal))
plt.show()
# Out:
# Test MSE: 3.999971466978165

# %% [markdown]
# ## Eksperymenty

# %%
def method_test(train_set, test_set, batch_size, arch, init, lr, epochs, name, interval=100, cutoff=None):
    y_norm, parameters = standardize_data(train_set['y'])
    methods = [None, 'moment', 'rmsprop']
    for method in methods:
        mse_list = []
        mlp = NeuralNetwork(arch, initalization=init)
        history = mlp.train(train_set['x'], y_norm, learning_rate=lr, epochs=epochs, batch_size=batch_size, return_history=True,
                                resize=True, X_test=test_set['x'], y_test=test_set['y'], cutoff=cutoff,
                                denormalize=parameters, info_interval=interval, mute_print=True, optimize=method)
        history.plot_loss()
    plt.suptitle(f"{name}, arch: {arch}, lr={lr}")
    plt.legend(methods)
    plt.show()

# %%
method_test(square_large_train, square_large_test, 250, [1, 5, 1], 'xavier', lr=0.1, epochs=5000,
           name='square-large', interval=50)

# %%
method_test(steps_large_train, steps_large_test, 250, [1, 5, 5, 1], 'he', lr=0.5, epochs=5000,
           name='steps-large', interval=50)

# %%
method_test(multimodal_train, multimodal_test, 250, [1, 10, 10, 1], 'xavier', lr=0.5, epochs=3000,
           name='multimodal-large', interval=50)
